# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import tensorflow as tf
import tensorflow_datasets as tfds
import tensorflow_hub as hub

import string
from string import digits
import re
import time
import numpy as np
import pandas as pd
import collections
import unicodedata

import os
import io


from bert import BertModelLayer
from bert.loader import StockBertConfig, load_stock_weights

from snownlp import SnowNLP

import  nltk.translate.bleu_score as bleu
import pynlpir

# %%
tf.config.list_physical_devices('GPU')
print("GPU Available: ", tf.test.is_gpu_available())
# Out:
# WARNING:tensorflow:From <ipython-input-2-b783941d6613>:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU Available:  True

# %%
pwd
# Out:
# 'C:\\Users\\user\\Project From Alex NLP'

# %%
path_to_zip = 'C:\\Users\\user\\Project From Alex NLP\\chi-eng.zip'
path_to_file = os.path.dirname(path_to_zip)+"\\chi-eng\\cmn.txt"
print(path_to_file)
# Out:
# C:\Users\user\Project From Alex NLP\chi-eng\cmn.txt

# %%
def preprocess_sentence(sentence):
  sentence = sentence.lower().strip()
  # creating a space between a word and the punctuation following it
  # eg: "he is a boy." => "he is a boy ."
  sentence = re.sub(r"([?.!,])", r" \1 ", sentence)
  sentence = re.sub(r'[" "]+', " ", sentence)
  # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
  sentence = re.sub(r"[^a-zA-Z?.!,]+", " ", sentence)
  sentence = sentence.strip()
  # adding a start and an end token to the sentence
  # so that the model know when to start and stop predicting.
#   sentence = '<start> ' + sentence + ' <end>'
  return sentence

# %%
# lines = io.open(path_to_file, encoding='UTF-8').read().strip().split('\n')

# %%
# for l in lines[0:4]:
#     eng = preprocess_sentence(l.split('\t')[0])
#     chi = l.split('\t')[1]

# %%
# (eng,chi)

# %%
# preprocess_sentence(lines[100].split('\t')[0])

# %%
# for l in lines[0:4]:
#     for w in l.split('\t'):
#         preprocess_sentence(w)
#         print(w)

# %%
# 1. Remove the accents
# 2. Clean the sentences
# 3. Return word pairs in the format: [ENGLISH, SPANISH]

def create_dataset(path, num1,num2):
  english = []
  chinese = []
  lines = io.open(path, encoding='UTF-8').read().strip().split('\n')

#   word_pairs = [[preprocess_sentence(w) for w in l.split('\t')]  for l in lines[:num_examples]]
  for l in lines[num1:num2]:
      eng = preprocess_sentence(l.split('\t')[0])
      chi = l.split('\t')[1]
      english.append(eng)
      chinese.append(chi)
        
  return english, chinese

# %%
en_tr, chi_tr = create_dataset(path_to_file, 0,20000)
print(en_tr[-1])
print(chi_tr[-1])
# Out:
# one man s meat is another man s poison .
# 甲之蜜糖，乙之砒霜。

# %%
len(en_tr),len(chi_tr)
# Out:
# (20000, 20000)

# %%
# !pip install snownlp

# %%
# s = SnowNLP(chi_tr[-1])
# s.words

# %%
en_val, chi_val = create_dataset(path_to_file,23000,23500)
len(en_val),len(chi_val)
# Out:
# (500, 500)

# %%
train_examples = tf.data.Dataset.from_tensor_slices((en_tr, chi_tr))
val_examples = tf.data.Dataset.from_tensor_slices((en_val, chi_val))

# %%
def convert_to_unicode(text):
    """Converts `text` to Unicode (if it's not already), assuming utf-8 input."""
    if isinstance(text, str):
        return text
    elif isinstance(text, bytes):
        return text.decode("utf-8", "ignore")
    else:
        raise ValueError("Unsupported string type: %s" % (type(text)))


def load_vocab(vocab_file):
    """Loads a vocabulary file into a dictionary."""
    vocab = collections.OrderedDict()
    index = 0
    with tf.io.gfile.GFile(vocab_file, "r") as reader:
        while True:
            token = convert_to_unicode(reader.readline())
            if not token:
                break
            token = token.strip()
            vocab[token] = index
            index += 1
    return vocab


def whitespace_tokenize(text):
    """Runs basic whitespace cleaning and splitting on a piece of text."""
    text = text.strip()
    if not text:
        return []
    tokens = text.split()
    return tokens

def convert_by_vocab(vocab, items):
    """Converts a sequence of [tokens|ids] using the vocab."""
    output = []
    for item in items:
        output.append(vocab[item])
    return output

class FullTokenizer(object):
    """Runs end-to-end tokenziation."""

    def __init__(self, vocab_file, do_lower_case=True):
        self.vocab = load_vocab(vocab_file)
        self.inv_vocab = {v: k for k, v in self.vocab.items()}
        self.basic_tokenizer = BasicTokenizer(do_lower_case=do_lower_case)
        self.wordpiece_tokenizer = WordpieceTokenizer(vocab=self.vocab)

    def tokenize(self, text):
        split_tokens = []
        for token in self.basic_tokenizer.tokenize(text):
            for sub_token in self.wordpiece_tokenizer.tokenize(token):
                split_tokens.append(sub_token)

        return split_tokens
    
    def convert_tokens_to_ids(self, tokens):
        return convert_by_vocab(self.vocab, tokens)

    def convert_ids_to_tokens(self, ids):
        return convert_by_vocab(self.inv_vocab, ids)


class BasicTokenizer(object):
    """Runs basic tokenization (punctuation splitting, lower casing, etc.)."""

    def __init__(self, do_lower_case=True):
        """Constructs a BasicTokenizer.
    
        Args:
          do_lower_case: Whether to lower case the input.
        """
        self.do_lower_case = do_lower_case

    def tokenize(self, text):
        """Tokenizes a piece of text."""
        text = convert_to_unicode(text)
        text = self._clean_text(text)

        # This was added on November 1st, 2018 for the multilingual and Chinese
        # models. This is also applied to the English models now, but it doesn't
        # matter since the English models were not trained on any Chinese data
        # and generally don't have any Chinese data in them (there are Chinese
        # characters in the vocabulary because Wikipedia does have some Chinese
        # words in the English Wikipedia.).
        text = self._tokenize_chinese_chars(text)

        orig_tokens = whitespace_tokenize(text)
        split_tokens = []
        for token in orig_tokens:
            if self.do_lower_case:
                token = token.lower()
                token = self._run_strip_accents(token)
            split_tokens.extend(self._run_split_on_punc(token))

        output_tokens = whitespace_tokenize(" ".join(split_tokens))
        return output_tokens

    def _run_strip_accents(self, text):
        """Strips accents from a piece of text."""
        text = unicodedata.normalize("NFD", text)
        output = []
        for char in text:
            cat = unicodedata.category(char)
            if cat == "Mn":
                continue
            output.append(char)
        return "".join(output)

    def _run_split_on_punc(self, text):
        """Splits punctuation on a piece of text."""
        chars = list(text)
        i = 0
        start_new_word = True
        output = []
        while i < len(chars):
            char = chars[i]
            if _is_punctuation(char):
                output.append([char])
                start_new_word = True
            else:
                if start_new_word:
                    output.append([])
                start_new_word = False
                output[-1].append(char)
            i += 1

        return ["".join(x) for x in output]

    def _tokenize_chinese_chars(self, text):
        """Adds whitespace around any CJK character."""
        output = []
        for char in text:
            cp = ord(char)
            if self._is_chinese_char(cp):
                output.append(" ")
                output.append(char)
                output.append(" ")
            else:
                output.append(char)
        return "".join(output)

    def _is_chinese_char(self, cp):
        """Checks whether CP is the codepoint of a CJK character."""
        # This defines a "chinese character" as anything in the CJK Unicode block:
        #   https://en.wikipedia.org/wiki/CJK_Unified_Ideographs_(Unicode_block)
        #
        # Note that the CJK Unicode block is NOT all Japanese and Korean characters,
        # despite its name. The modern Korean Hangul alphabet is a different block,
        # as is Japanese Hiragana and Katakana. Those alphabets are used to write
        # space-separated words, so they are not treated specially and handled
        # like the all of the other languages.
        if ((cp >= 0x4E00 and cp <= 0x9FFF) or  #
                (cp >= 0x3400 and cp <= 0x4DBF) or  #
                (cp >= 0x20000 and cp <= 0x2A6DF) or  #
                (cp >= 0x2A700 and cp <= 0x2B73F) or  #
                (cp >= 0x2B740 and cp <= 0x2B81F) or  #
                (cp >= 0x2B820 and cp <= 0x2CEAF) or
                (cp >= 0xF900 and cp <= 0xFAFF) or  #
                (cp >= 0x2F800 and cp <= 0x2FA1F)):  #
            return True

        return False

    def _clean_text(self, text):
        """Performs invalid character removal and whitespace cleanup on text."""
        output = []
        for char in text:
            cp = ord(char)
            if cp == 0 or cp == 0xfffd or _is_control(char):
                continue
            if _is_whitespace(char):
                output.append(" ")
            else:
                output.append(char)
        return "".join(output)


class WordpieceTokenizer(object):
    """Runs WordPiece tokenziation."""

    def __init__(self, vocab, unk_token="[UNK]", max_input_chars_per_word=200):
        self.vocab = vocab
        self.unk_token = unk_token
        self.max_input_chars_per_word = max_input_chars_per_word

    def tokenize(self, text):
        """Tokenizes a piece of text into its word pieces.
    
        This uses a greedy longest-match-first algorithm to perform tokenization
        using the given vocabulary.
    
        For example:
          input = "unaffable"
          output = ["un", "##aff", "##able"]
    
        Args:
          text: A single token or whitespace separated tokens. This should have
            already been passed through `BasicTokenizer.
    
        Returns:
          A list of wordpiece tokens.
        """

        text = convert_to_unicode(text)

        output_tokens = []
        for token in whitespace_tokenize(text):
            chars = list(token)
            if len(chars) > self.max_input_chars_per_word:
                output_tokens.append(self.unk_token)
                continue

            is_bad = False
            start = 0
            sub_tokens = []
            while start < len(chars):
                end = len(chars)
                cur_substr = None
                while start < end:
                    substr = "".join(chars[start:end])
                    if start > 0:
                        substr = "##" + substr
                    if substr in self.vocab:
                        cur_substr = substr
                        break
                    end -= 1
                if cur_substr is None:
                    is_bad = True
                    break
                sub_tokens.append(cur_substr)
                start = end

            if is_bad:
                output_tokens.append(self.unk_token)
            else:
                output_tokens.extend(sub_tokens)
        return output_tokens

def _is_whitespace(char):
    """Checks whether `chars` is a whitespace character."""
    # \t, \n, and \r are technically contorl characters but we treat them
    # as whitespace since they are generally considered as such.
    if char == " " or char == "\t" or char == "\n" or char == "\r":
        return True
    cat = unicodedata.category(char)
    if cat == "Zs":
        return True
    return False


def _is_control(char):
    """Checks whether `chars` is a control character."""
    # These are technically control characters but we count them as whitespace
    # characters.
    if char == "\t" or char == "\n" or char == "\r":
        return False
    cat = unicodedata.category(char)
    if cat.startswith("C"):
        return True
    return False


def _is_punctuation(char):
    """Checks whether `chars` is a punctuation character."""
    cp = ord(char)
    # We treat all non-letter/number ASCII as punctuation.
    # Characters such as "^", "$", and "`" are not in the Unicode
    # Punctuation class but we treat them as punctuation anyways, for
    # consistency.
    if ((cp >= 33 and cp <= 47) or (cp >= 58 and cp <= 64) or
            (cp >= 91 and cp <= 96) or (cp >= 123 and cp <= 126)):
        return True
    cat = unicodedata.category(char)
    if cat.startswith("P"):
        return True
    return False

# %%
# tokenizer_en = tfds.features.text.SubwordTextEncoder.build_from_corpus(
#     en_tr, target_vocab_size=2**13)
# tokenizer_en.save_to_file('vocab_english')

# sample_string = 'Transformer is awesome.'
# tokenized_string = tokenizer_en.encode(sample_string)
# for ts in tokenized_string:
#   print ('{} ----> {}'.format(ts, tokenizer_en.decode([ts])))

# %%
tokenizer_chin = tfds.features.text.SubwordTextEncoder.build_from_corpus(
    chi_tr, target_vocab_size=2**13)
tokenizer_chin.save_to_file('vocab_chinese')

# %%
sample_string = '很高興認識你'
tokenized_string = tokenizer_chin.encode(sample_string)
for ts in tokenized_string:
  print ('{} ----> {}'.format(ts, tokenizer_chin.decode([ts])))
# Out:
# 4573 ----> 很高興
# 575 ----> 認識
# 9 ----> 你

# %%
tokenizer_eng = FullTokenizer(
    vocab_file= 'uncased_L-12_H-768_A-12/vocab.txt',
    do_lower_case=True)

test_tokens = tokenizer_eng.tokenize(en_tr[100])
test_ids = tokenizer_eng.convert_tokens_to_ids(['[CLS]'] + test_tokens + ['[SEP]'])
print(test_ids)
print(tokenizer_eng.convert_ids_to_tokens(test_ids))
# Out:
# [101, 9241, 2039, 1012, 102]
# ['[CLS]', 'hurry', 'up', '.', '[SEP]']

# %%
MAX_SEQ_LENGTH = 40


def encode(en, chi, seq_length=MAX_SEQ_LENGTH):
  tokens_eng = tokenizer_eng.tokenize(tf.compat.as_text(en.numpy()))
  lang1 = tokenizer_eng.convert_tokens_to_ids(['[CLS]'] + tokens_eng + ['[SEP]'])
  if len(lang1)<seq_length:
    lang1 = lang1 + list(np.zeros(seq_length - len(lang1), 'int32'))

  lang2 = [tokenizer_chin.vocab_size] + tokenizer_chin.encode(tf.compat.as_text(chi.numpy())) + [tokenizer_chin.vocab_size + 1]
  if len(lang2)<seq_length:
    lang2 = lang2 + list(np.zeros(seq_length - len(lang2), 'int32'))

  return lang1, lang2

# %%
def tf_encode(en, chi):
  result_en, result_chi = tf.py_function(encode, [en, chi], [tf.int32, tf.int32])
  result_chi.set_shape([None])
  result_en.set_shape([None])

  return result_en, result_chi

# %%
def filter_max_length(x, y, max_length=MAX_SEQ_LENGTH):
  return tf.logical_and(tf.size(x) <= max_length,
                        tf.size(y) <= max_length)

# %%
print(len(chi_tr))
# Out:
# 20000

# %%
BUFFER_SIZE = 20000
BATCH_SIZE = 64

train_dataset = train_examples.map(tf_encode)
# train_dataset = tf.io.decode_raw(train_dataset, tf.int32)
train_dataset = train_dataset.filter(filter_max_length)

# cache the dataset to memory to get a speedup while reading from it.
train_dataset = train_dataset.cache()
train_dataset = train_dataset.shuffle(BUFFER_SIZE).padded_batch(
    BATCH_SIZE, padded_shapes=([-1], [-1]), drop_remainder=True)
train_dataset = train_dataset.prefetch(tf.data.experimental.AUTOTUNE)

val_dataset = val_examples.map(
    lambda en, chi: tf.py_function(encode, [en, chi], [tf.int32, tf.int32]))
val_dataset = val_dataset.filter(filter_max_length)
val_dataset = val_dataset.padded_batch(BATCH_SIZE, padded_shapes=([-1], [-1]))

# %% [markdown]
# # Positional Encoding

# %%
def get_angles(pos, i, d_model):
  angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
  return pos * angle_rates

# %%
def positional_encoding(position, d_model):
    angle_rads = get_angles(np.arange(position)[:, np.newaxis],
                            np.arange(d_model)[np.newaxis, :],
                            d_model)

    # apply sin to even indices in the array; 2i
    sines = np.sin(angle_rads[:, 0::2])

    # apply cos to odd indices in the array; 2i+1
    cosines = np.cos(angle_rads[:, 1::2])

    pos_encoding = np.concatenate([sines, cosines], axis=-1)

    pos_encoding = pos_encoding[np.newaxis, ...]

    return tf.cast(pos_encoding, dtype=tf.float32)

# %%
def create_padding_mask(seq):
  seq = tf.cast(tf.math.equal(seq, 0), tf.float32)
  
  # add extra dimensions so that we can add the padding
  # to the attention logits.
  return seq[:, tf.newaxis, tf.newaxis, :]  # (batch_size, 1, 1, seq_len)

# %%
def create_look_ahead_mask(size):
    mask = 1 - tf.linalg.band_part(tf.ones((size, size)), -1, 0)
    return mask  # (seq_len, seq_len)

# %%
def scaled_dot_product_attention(q, k, v, mask):
    """Calculate the attention weights.
    q, k, v must have matching leading dimensions.
    k, v must have matching penultimate dimension, i.e.: seq_len_k = seq_len_v.
    The mask has different shapes depending on its type(padding or look ahead) 
    but it must be broadcastable for addition.
    
    Args:
      q: query shape == (..., seq_len_q, depth)
      k: key shape == (..., seq_len_k, depth)
      v: value shape == (..., seq_len_v, depth_v)
      mask: Float tensor with shape broadcastable 
            to (..., seq_len_q, seq_len_k). Defaults to None.
      
    Returns:
      output, attention_weights
    """

    matmul_qk = tf.matmul(q, k, transpose_b=True)  # (..., seq_len_q, seq_len_k)

    # scale matmul_qk
    dk = tf.cast(tf.shape(k)[-1], tf.float32)
    scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)

    # add the mask to the scaled tensor.
    if mask is not None:
        scaled_attention_logits += (mask * -1e9)

        # softmax is normalized on the last axis (seq_len_k) so that the scores
    # add up to 1.
    attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)  # (..., seq_len_q, seq_len_k)

    output = tf.matmul(attention_weights, v)  # (..., seq_len_q, depth_v)

    return output, attention_weights

# %%
class MultiHeadAttention(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads):
        super(MultiHeadAttention, self).__init__()
        self.num_heads = num_heads
        self.d_model = d_model

        assert d_model % self.num_heads == 0

        self.depth = d_model // self.num_heads

        self.wq = tf.keras.layers.Dense(d_model)
        self.wk = tf.keras.layers.Dense(d_model)
        self.wv = tf.keras.layers.Dense(d_model)

        self.dense = tf.keras.layers.Dense(d_model)

    def split_heads(self, x, batch_size):
        """Split the last dimension into (num_heads, depth).
        Transpose the result such that the shape is (batch_size, num_heads, seq_len, depth)
        """
        x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth))
        return tf.transpose(x, perm=[0, 2, 1, 3])

    def call(self, v, k, q, mask):
        batch_size = tf.shape(q)[0]

        q = self.wq(q)  # (batch_size, seq_len, d_model)
        k = self.wk(k)  # (batch_size, seq_len, d_model)
        v = self.wv(v)  # (batch_size, seq_len, d_model)

        q = self.split_heads(q, batch_size)  # (batch_size, num_heads, seq_len_q, depth)
        k = self.split_heads(k, batch_size)  # (batch_size, num_heads, seq_len_k, depth)
        v = self.split_heads(v, batch_size)  # (batch_size, num_heads, seq_len_v, depth)

        # scaled_attention.shape == (batch_size, num_heads, seq_len_q, depth)
        # attention_weights.shape == (batch_size, num_heads, seq_len_q, seq_len_k)
        scaled_attention, attention_weights = scaled_dot_product_attention(
            q, k, v, mask)

        scaled_attention = tf.transpose(scaled_attention,
                                        perm=[0, 2, 1, 3])  # (batch_size, seq_len_q, num_heads, depth)

        concat_attention = tf.reshape(scaled_attention,
                                      (batch_size, -1, self.d_model))  # (batch_size, seq_len_q, d_model)

        output = self.dense(concat_attention)  # (batch_size, seq_len_q, d_model)

        return output, attention_weights

# %%
temp_mha = MultiHeadAttention(d_model=512, num_heads=8)
y = tf.random.uniform((1, 60, 768))  # (batch_size, encoder_sequence, d_model)
q = tf.random.uniform((1, 60, 512))  # (batch_size, encoder_sequence, d_model)
out, attn = temp_mha(y, k=y, q=q, mask=None)
out.shape, attn.shape
# Out:
# (TensorShape([1, 60, 512]), TensorShape([1, 8, 60, 60]))

# %%
def point_wise_feed_forward_network(d_model, dff):
    return tf.keras.Sequential([
        tf.keras.layers.Dense(dff, activation='relu'),  # (batch_size, seq_len, dff)
        tf.keras.layers.Dense(d_model)  # (batch_size, seq_len, d_model)
    ])

# %%
def build_encoder(config_file):
    with tf.io.gfile.GFile(config_file, "r") as reader:
        stock_params = StockBertConfig.from_json_string(reader.read())
        bert_params = stock_params.to_bert_model_layer_params()

    return BertModelLayer.from_params(bert_params, name="bert")

# %%
class DecoderLayer(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads, dff, rate=0.1):
        super(DecoderLayer, self).__init__()

        self.mha1 = MultiHeadAttention(d_model, num_heads)
        self.mha2 = MultiHeadAttention(d_model, num_heads)

        self.ffn = point_wise_feed_forward_network(d_model, dff)

        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm3 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

        self.dropout1 = tf.keras.layers.Dropout(rate)
        self.dropout2 = tf.keras.layers.Dropout(rate)
        self.dropout3 = tf.keras.layers.Dropout(rate)


    def call(self, x, enc_output, training,
             look_ahead_mask, padding_mask):
        # enc_output.shape == (batch_size, input_seq_len, d_model)

        attn1, attn_weights_block1 = self.mha1(x, x, x, look_ahead_mask)  # (batch_size, target_seq_len, d_model)
        attn1 = self.dropout1(attn1, training=training)
        out1 = self.layernorm1(attn1 + x)

        attn2, attn_weights_block2 = self.mha2(
            enc_output, enc_output, out1, padding_mask)  # (batch_size, target_seq_len, d_model)
        attn2 = self.dropout2(attn2, training=training)
        out2 = self.layernorm2(attn2 + out1)  # (batch_size, target_seq_len, d_model)

        ffn_output = self.ffn(out2)  # (batch_size, target_seq_len, d_model)
        ffn_output = self.dropout3(ffn_output, training=training)
        out3 = self.layernorm3(ffn_output + out2)  # (batch_size, target_seq_len, d_model)

        return out3, attn_weights_block1, attn_weights_block2

# %%
sample_decoder_layer = DecoderLayer(512, 8, 2048)
sample_encoder_output = tf.random.uniform((64, 128, 768))

sample_decoder_layer_output, _, _ = sample_decoder_layer(
    tf.random.uniform((64, 50, 512)), sample_encoder_output,
    False, None, None)

sample_decoder_layer_output.shape  # (batch_size, target_seq_len, d_model)
# Out:
# TensorShape([64, 50, 512])

# %%
class Decoder(tf.keras.layers.Layer):
    def __init__(self, num_layers, d_model, num_heads, dff, target_vocab_size,
                 rate=0.1):
        super(Decoder, self).__init__()

        self.d_model = d_model
        self.num_layers = num_layers

        self.embedding = tf.keras.layers.Embedding(target_vocab_size, d_model)
        self.pos_encoding = positional_encoding(target_vocab_size, self.d_model)

        self.dec_layers = [DecoderLayer(d_model, num_heads, dff, rate)
                           for _ in range(num_layers)]
        self.dropout = tf.keras.layers.Dropout(rate)

    def call(self, x, enc_output, training,
             look_ahead_mask, padding_mask):
        seq_len = tf.shape(x)[1]
        attention_weights = {}

        x = self.embedding(x)  # (batch_size, target_seq_len, d_model)
        x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
        x += self.pos_encoding[:, :seq_len, :]

        x = self.dropout(x, training=training)

        for i in range(self.num_layers):
            x, block1, block2 = self.dec_layers[i](x, enc_output, training,
                                                   look_ahead_mask, padding_mask)

            attention_weights['decoder_layer{}_block1'.format(i + 1)] = block1
            attention_weights['decoder_layer{}_block2'.format(i + 1)] = block2

        # x.shape == (batch_size, target_seq_len, d_model)
        return x, attention_weights

# %%
sample_decoder = Decoder(num_layers=2, d_model=512, num_heads=8, 
                         dff=2048, target_vocab_size=8000)

output, attn = sample_decoder(tf.random.uniform((64, 26)), 
                              enc_output=sample_encoder_output, 
                              training=False, look_ahead_mask=None, 
                              padding_mask=None)

output.shape, attn['decoder_layer2_block2'].shape
# Out:
# (TensorShape([64, 26, 512]), TensorShape([64, 8, 26, 128]))

# %%
class Config(object):
  def __init__(self, num_layers, d_model, dff, num_heads):
    self.num_layers = num_layers
    self.d_model = d_model
    self.dff = dff
    self.num_heads= num_heads

# %%
from bert.loader import map_to_stock_variable_name
# /content/drive/My Drive/machine translation/transformer/bert
class Transformer(tf.keras.Model):
  def __init__(self, config,
               target_vocab_size, 
               bert_config_file,
               bert_training=False, 
               rate=0.1,
               name='transformer'):
      super(Transformer, self).__init__(name=name)

      self.encoder = build_encoder(config_file=bert_config_file)
      self.encoder.trainable = bert_training

      self.decoder = Decoder(config.num_layers, config.d_model, 
                             config.num_heads, config.dff, target_vocab_size, rate)

      self.final_layer = tf.keras.layers.Dense(target_vocab_size)


  def load_stock_weights(self, bert: BertModelLayer, ckpt_file):
      assert isinstance(bert, BertModelLayer), "Expecting a BertModelLayer instance as first argument"
      assert tf.compat.v1.train.checkpoint_exists(ckpt_file), "Checkpoint does not exist: {}".format(ckpt_file)
      ckpt_reader = tf.train.load_checkpoint(ckpt_file)

      bert_prefix = 'transformer/bert'

      weights = []
      for weight in bert.weights:
          stock_name = map_to_stock_variable_name(weight.name, bert_prefix)
          if ckpt_reader.has_tensor(stock_name):
              value = ckpt_reader.get_tensor(stock_name)
              weights.append(value)
          else:
              raise ValueError("No value for:[{}], i.e.:[{}] in:[{}]".format(weight.name, stock_name, ckpt_file))
      bert.set_weights(weights)
      print("Done loading {} BERT weights from: {} into {} (prefix:{})".format(
          len(weights), ckpt_file, bert, bert_prefix))

  def restore_encoder(self, bert_ckpt_file):
      # loading the original pre-trained weights into the BERT layer:
      self.load_stock_weights(self.encoder, bert_ckpt_file)

  def call(self, inp, tar, training, look_ahead_mask, dec_padding_mask):
      enc_output = self.encoder(inp, training=self.encoder.trainable)  # (batch_size, inp_seq_len, d_model)

      # dec_output.shape == (batch_size, tar_seq_len, d_model)
      dec_output, attention_weights = self.decoder(
          tar, enc_output, training, look_ahead_mask, dec_padding_mask)

      final_output = self.final_layer(dec_output)  # (batch_size, tar_seq_len, target_vocab_size)

      return final_output, attention_weights

# %%
target_vocab_size = tokenizer_chin.vocab_size + 2
dropout_rate = 0.1
config = Config(num_layers=6, d_model=512, dff=1024, num_heads=8)

# %%
# gs_folder_bert
# uncased_L-12_H-768_A-12
MODEL_DIR = "uncased_L-12_H-768_A-12"
bert_config_file = os.path.join(MODEL_DIR, "bert_config.json")
bert_ckpt_file = os.path.join(MODEL_DIR, 'bert_model.ckpt')

# with tpu_strategy.scope():
transformer = Transformer(config=config,
                          target_vocab_size=target_vocab_size,
                          bert_config_file=bert_config_file)
  
inp = tf.random.uniform((BATCH_SIZE, MAX_SEQ_LENGTH))
tar_inp = tf.random.uniform((BATCH_SIZE, MAX_SEQ_LENGTH))
fn_out, _ = transformer(inp, tar_inp, 
                        True,
                        look_ahead_mask=None,
                        dec_padding_mask=None)
print(tar_inp.shape) # (batch_size, tar_seq_len) 
print(fn_out.shape)  # (batch_size, tar_seq_len, target_vocab_size) 

# init bert pre-trained weights
transformer.restore_encoder(bert_ckpt_file)
# Out:
# (64, 40)
# (64, 40, 7320)
# WARNING:tensorflow:From <ipython-input-34-c616cf2f44b4>:23: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# WARNING:tensorflow:From <ipython-input-34-c616cf2f44b4>:23: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# Done loading 196 BERT weights from: uncased_L-12_H-768_A-12\bert_model.ckpt into <bert.model.BertModelLayer object at 0x000001F224065CC8> (prefix:transformer/bert)

# %%
transformer.summary()
# Out:
# Model: "transformer"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bert (BertModelLayer)        multiple                  108890112
# _________________________________________________________________
# decoder_1 (Decoder)          multiple                  24247296
# _________________________________________________________________
# dense_94 (Dense)             multiple                  3755160
# =================================================================
# Total params: 136,892,568
# Trainable params: 28,002,456
# Non-trainable params: 108,890,112
# _________________________________________________________________

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, d_model, warmup_steps=4000):
        super(CustomSchedule, self).__init__()

        self.d_model = d_model
        self.d_model = tf.cast(self.d_model, tf.float32)

        self.warmup_steps = warmup_steps
    
    def __call__(self, step):
        arg1 = tf.math.rsqrt(step)
        arg2 = step * (self.warmup_steps ** -1.5)

        return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

# %%
learning_rate = CustomSchedule(config.d_model)

optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98,
                                     epsilon=1e-9)

# %%
temp_learning_rate_schedule = CustomSchedule(config.d_model)
import matplotlib.pyplot as plt

plt.plot(temp_learning_rate_schedule(tf.range(40000, dtype=tf.float32)))
plt.ylabel("Learning Rate")
plt.xlabel("Train Step")

# %%
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

# %%
def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_mean(loss_)

# %%
train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(
    name='train_accuracy')

# %%
checkpoint_path = "/checkpoints/train_nmt_eng_to_chi_bert"

ckpt = tf.train.Checkpoint(transformer=transformer,
                           optimizer=optimizer)

ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# if a checkpoint exists, restore the latest checkpoint.
if ckpt_manager.latest_checkpoint:
    ckpt.restore(ckpt_manager.latest_checkpoint)
    print('Latest checkpoint restored!!')

# %%
def create_masks(inp, tar):
    # Used in the 2nd attention block in the decoder.
    # This padding mask is used to mask the encoder outputs.
    dec_padding_mask = create_padding_mask(inp)

    # Used in the 1st attention block in the decoder.
    # It is used to pad and mask future tokens in the input received by 
    # the decoder.
    look_ahead_mask = create_look_ahead_mask(tf.shape(tar)[1])
    dec_target_padding_mask = create_padding_mask(tar)
    combined_mask = tf.maximum(dec_target_padding_mask, look_ahead_mask)

    return combined_mask, dec_padding_mask

# %%
@tf.function
def train_step(inp, tar):
    tar_inp = tar[:, :-1]
    tar_real = tar[:, 1:]

    combined_mask, dec_padding_mask = create_masks(inp, tar_inp)

    
    with tf.GradientTape() as tape:
        predictions, _ = transformer(inp, tar_inp, 
                                     True,
                                     combined_mask,
                                     dec_padding_mask)
        loss = loss_function(tar_real, predictions)

    gradients = tape.gradient(loss, transformer.trainable_variables)
    optimizer.apply_gradients(zip(gradients, transformer.trainable_variables))

    train_loss(loss)
    train_accuracy(tar_real, predictions)

# %%
EPOCHS = 20

for epoch in range(EPOCHS):
    start = time.time()

    train_loss.reset_states()
    train_accuracy.reset_states()

    # inp -> chinese, tar -> english
    for (batch, (inp, tar)) in enumerate(train_dataset):
        train_step(inp, tar)

        if batch % 500 == 0:
            print('Epoch {} Batch {} Loss {:.4f} Accuracy {:.4f}'.format(
                epoch + 1, batch, train_loss.result(), train_accuracy.result()))

    if (epoch + 1) % 1 == 0:
        ckpt_save_path = ckpt_manager.save()
        print('Saving checkpoint for epoch {} at {}'.format(epoch + 1,
                                                            ckpt_save_path))

    print('Epoch {} Loss {:.4f} Accuracy {:.4f}'.format(epoch + 1,
                                                        train_loss.result(),
                                                        train_accuracy.result()))

    print('Time taken for 1 epoch: {} secs\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 1.5124 Accuracy 0.0000
# Saving checkpoint for epoch 1 at /checkpoints/train_nmt_eng_to_chi_bert\ckpt-1
# Epoch 1 Loss 1.1780 Accuracy 0.0358
# Time taken for 1 epoch: 88.95984721183777 secs
#
# Epoch 2 Batch 0 Loss 0.9579 Accuracy 0.0517
# Saving checkpoint for epoch 2 at /checkpoints/train_nmt_eng_to_chi_bert\ckpt-2
# Epoch 2 Loss 0.9586 Accuracy 0.0523
# Time taken for 1 epoch: 63.46627998352051 secs
#
# Epoch 3 Batch 0 Loss 0.9504 Accuracy 0.0537
# Saving checkpoint for epoch 3 at /checkpoints/train_nmt_eng_to_chi_bert\ckpt-3
# Epoch 3 Loss 0.8610 Accuracy 0.0551
# Time taken for 1 epoch: 63.559361696243286 secs
#
# Epoch 4 Batch 0 Loss 0.8376 Accuracy 0.0573
# Saving checkpoint for epoch 4 at /checkpoints/train_nmt_eng_to_chi_bert\ckpt-4
# Epoch 4 Loss 0.7559 Accuracy 0.0584
# Time taken for 1 epoch: 63.441171407699585 secs
#
# Epoch 5 Batch 0 Loss 0.6925 Accuracy 0.0593
# Saving checkpoint for epoch 5 at /checkpoints/train_nmt_eng_to_chi_bert\ckpt-5
# Epoch 5 Loss 0.6566 Accuracy 0.0628
# Time taken for 1 epoch: 63.033703327178955 secs
#
# Epoch 6 Batch 0 Loss 0.5763 Accuracy 0.0741
# Saving checkpoint for epoch 6 at /checkpoints/train_nmt_eng_to_chi_bert\ckpt-6
# Epoch 6 Loss 0.5611 Accuracy 0.0689
# Time taken for 1 epoch: 62.817689418792725 secs
#
# Epoch 7 Batch 0 Loss 0.5144 Accuracy 0.0781
# Saving checkpoint for epoch 7 at /checkpoints/train_nmt_eng_to_chi_bert\ckpt-7
# Epoch 7 Loss 0.4718 Accuracy 0.0768
# Time taken for 1 epoch: 62.82351326942444 secs
#
# Epoch 8 Batch 0 Loss 0.3633 Accuracy 0.0777
# Saving checkpoint for epoch 8 at /checkpoints/train_nmt_eng_to_chi_bert\ckpt-8
# Epoch 8 Loss 0.3946 Accuracy 0.0853
# Time taken for 1 epoch: 62.5987823009491 secs
#
# Epoch 9 Batch 0 Loss 0.3156 Accuracy 0.0962
# Saving checkpoint for epoch 9 at /checkpoints/train_nmt_eng_to_chi_bert\ckpt-9
# Epoch 9 Loss 0.3295 Accuracy 0.0936
# Time taken for 1 epoch: 62.8592255115509 secs
#
# Epoch 10 Batch 0 Loss 0.2354 Accuracy 0.1122
# Saving checkpoint for epoch 10 at /checkpoints/train_nmt_eng_to_chi_bert\ckpt-10
# Epoch 10 Loss 0.2806 Accuracy 0.1007
# Time taken for 1 epoch: 62.7454252243042 secs
#
# Epoch 11 Batch 0 Loss 0.2034 Accuracy 0.1126
# Saving checkpoint for epoch 11 at /checkpoints/train_nmt_eng_to_chi_bert\ckpt-11
# Epoch 11 Loss 0.2445 Accuracy 0.1063
# Time taken for 1 epoch: 62.97128510475159 secs
#
# Epoch 12 Batch 0 Loss 0.2163 Accuracy 0.1198
# Saving checkpoint for epoch 12 at /checkpoints/train_nmt_eng_to_chi_bert\ckpt-12
# Epoch 12 Loss 0.2249 Accuracy 0.1095
# Time taken for 1 epoch: 63.160656452178955 secs
#
# Epoch 13 Batch 0 Loss 0.1394 Accuracy 0.1142
# Saving checkpoint for epoch 13 at /checkpoints/train_nmt_eng_to_chi_bert\ckpt-13
# Epoch 13 Loss 0.2118 Accuracy 0.1120
# Time taken for 1 epoch: 63.37769818305969 secs
#
# Epoch 14 Batch 0 Loss 0.2153 Accuracy 0.1126
# Saving checkpoint for epoch 14 at /checkpoints/train_nmt_eng_to_chi_bert\ckpt-14
# Epoch 14 Loss 0.2039 Accuracy 0.1135
# Time taken for 1 epoch: 63.311203956604004 secs
#
# Epoch 15 Batch 0 Loss 0.1454 Accuracy 0.1282
# Saving checkpoint for epoch 15 at /checkpoints/train_nmt_eng_to_chi_bert\ckpt-15
# Epoch 15 Loss 0.1814 Accuracy 0.1182
# Time taken for 1 epoch: 62.86919951438904 secs
#
# Epoch 16 Batch 0 Loss 0.1556 Accuracy 0.1210
# Saving checkpoint for epoch 16 at /checkpoints/train_nmt_eng_to_chi_bert\ckpt-16
# Epoch 16 Loss 0.1693 Accuracy 0.1210
# Time taken for 1 epoch: 62.73299288749695 secs
#
# Epoch 17 Batch 0 Loss 0.1740 Accuracy 0.1310
# Saving checkpoint for epoch 17 at /checkpoints/train_nmt_eng_to_chi_bert\ckpt-17
# Epoch 17 Loss 0.1585 Accuracy 0.1234
# Time taken for 1 epoch: 62.60146927833557 secs
#
# Epoch 18 Batch 0 Loss 0.0952 Accuracy 0.1334
# Saving checkpoint for epoch 18 at /checkpoints/train_nmt_eng_to_chi_bert\ckpt-18
# Epoch 18 Loss 0.1457 Accuracy 0.1263
# Time taken for 1 epoch: 62.60334300994873 secs
#
# Epoch 19 Batch 0 Loss 0.1150 Accuracy 0.1306
# Saving checkpoint for epoch 19 at /checkpoints/train_nmt_eng_to_chi_bert\ckpt-19
# Epoch 19 Loss 0.1433 Accuracy 0.1272
# Time taken for 1 epoch: 62.841732025146484 secs
#
# Epoch 20 Batch 0 Loss 0.1185 Accuracy 0.1326
# Saving checkpoint for epoch 20 at /checkpoints/train_nmt_eng_to_chi_bert\ckpt-20
# Epoch 20 Loss 0.1434 Accuracy 0.1272
# Time taken for 1 epoch: 62.94994616508484 secs

# %% [markdown]
# # Evaluate

# %%
def encode_en(en):
    tokens_en = tokenizer_eng.tokenize(en)
    lang1 = tokenizer_eng.convert_tokens_to_ids(['[CLS]'] + tokens_en + ['[SEP]'])
    return lang1

# %%
def evaluate(transformer, inp_sentence):
    # normalize input sentence
    inp_sentence = encode_en(inp_sentence)
    encoder_input = tf.expand_dims(inp_sentence, 0)

    # as the target is english, the first word to the transformer should be the
    # english start token.
    decoder_input = [tokenizer_chin.vocab_size]
    output = tf.expand_dims(decoder_input, 0)

    for i in range(MAX_SEQ_LENGTH):
        combined_mask, dec_padding_mask = create_masks(
            encoder_input, output)

        # predictions.shape == (batch_size, seq_len, vocab_size)
        predictions, attention_weights = transformer(encoder_input,
                                                     output,
                                                     False,
                                                     combined_mask,
                                                     dec_padding_mask)

        # select the last word from the seq_len dimension
        predictions = predictions[:, -1:, :]  # (batch_size, 1, vocab_size)

        predicted_id = tf.cast(tf.argmax(predictions, axis=-1), tf.int32)

        # return the result if the predicted_id is equal to the end token
        if tf.equal(predicted_id, tokenizer_chin.vocab_size + 1):
            return tf.squeeze(output, axis=0), attention_weights

        # concatentate the predicted_id to the output which is given to the decoder
        # as its input.
        output = tf.concat([output, predicted_id], axis=-1)

    return tf.squeeze(output, axis=0), attention_weights

# %%
def plot_attention_weights(attention, sentence, result, layer):
  fig = plt.figure(figsize=(16, 8))
  
  test_tokens = tokenizer_eng.tokenize(sentence)
  sentence = tokenizer_eng.convert_tokens_to_ids(test_tokens)

#   sentence = tokenizer_ques.tokenize(sentence) #.encode(sentence)
  
  attention = tf.squeeze(attention[layer], axis=0)
  
  for head in range(attention.shape[0]):
    ax = fig.add_subplot(2, 4, head+1)
    
    # plot the attention weights
    ax.matshow(attention[head][:-1, :], cmap='viridis')

    fontdict = {'fontsize': 10}
    
    ax.set_xticks(range(len(sentence)+2))
    ax.set_yticks(range(len(result)))
    
    ax.set_ylim(len(result)-1.5, -0.5)
        
    ax.set_xticklabels(
        ['<start>']+[tokenizer_eng.convert_ids_to_tokens([i]) for i in sentence]+['<end>'], 
        fontdict=fontdict, rotation=90)
    
    ax.set_yticklabels([tokenizer_eng.decode([i]) for i in result 
                        if i < tokenizer_chin.vocab_size], 
                       fontdict=fontdict)
    
    ax.set_xlabel('Head {}'.format(head+1))
  
  plt.tight_layout()
  plt.show()

# %%
def translate(transformer, sentence, plot=''):
    result, attention_weights = evaluate(transformer, sentence)

    predicted_sentence = tokenizer_chin.decode([i for i in result
                                              if i < tokenizer_chin.vocab_size])

    print('Input: {}'.format(sentence))
    print('Predicted Translation: {}'.format(predicted_sentence))
    
    if plot:
        plot_attention_weights(attention_weights, sentence, result, plot)
    
    return predicted_sentence

# %%
translate(transformer, 'How are you?')
# Out:
# Input: How are you?
# Predicted Translation: 机场机场机场机场机场机场机场机场机场机场机场机场走的會發生我弟弟會發生我弟弟會發生我弟弟會發生我弟弟會發生我弟弟會發生會發生會發生會發生會發生會發生會發生會發生會發生會發生會發生會發生會發生會發生會發生會發生會發生
# '机场机场机场机场机场机场机场机场机场机场机场机场走的會發生我弟弟會發生我弟弟會發生我弟弟會發生我弟弟會發生我弟弟會發生會發生會發生會發生會發生會發生會發生會發生會發生會發生會發生會發生會發生會發生會發生會發生會發生'

# %%
translate(transformer, 'Where are you going?')
# Out:
# Input: Where are you going?
# Predicted Translation: 机场机场句話句話句話句話失敗句話失敗句話失敗句話失敗句話失敗句話失敗失敗失敗失敗失敗失敗失敗句話失敗句話失敗句話失敗失敗失敗失敗失敗失敗失敗失敗失敗失敗句話失敗
# '机场机场句話句話句話句話失敗句話失敗句話失敗句話失敗句話失敗句話失敗失敗失敗失敗失敗失敗失敗句話失敗句話失敗句話失敗失敗失敗失敗失敗失敗失敗失敗失敗失敗句話失敗'

# %%
translate(transformer, 'Nice to meet you')
# Out:
# Input: Nice to meet you
# Predicted Translation: 對不起認識你認識你。
# '對不起認識你認識你。'

# %% [markdown]
# # Save Weights

# %%
transformer.save_weights('/weights/nmt_en_2_chi_bert_ckpt')

# %%
new_transformer = Transformer(config=config,
                          target_vocab_size=target_vocab_size,
                          bert_config_file=bert_config_file)
  
fn_out, _ = new_transformer(inp, tar_inp, 
                        True,
                        look_ahead_mask=None,
                        dec_padding_mask=None)
new_transformer.load_weights('/weights/nmt_en_2_chi_bert_ckpt')

# %%
translate(new_transformer, "I am full")
# Out:
# Input: I am full
# Predicted Translation: “饱了。
# '“饱了。'

# %%
translate(new_transformer, 'How are you?')
# Out:
# Input: How are you?
# Predicted Translation: 你怎么们么？
# '你怎么们么？'

# %%
translate(new_transformer, 'Where are you going?')
# Out:
# Input: Where are you going?
# Predicted Translation: 你要去哪裡哪儿，你的哪处。
# '你要去哪裡哪儿，你的哪处。'

# %%
translate(new_transformer, 'Nice to meet you')
# Out:
# Input: Nice to meet you
# Predicted Translation: 對不起認識你認識你。
# '對不起認識你認識你。'

# %%
translate(new_transformer, 'I love you')
# Out:
# Input: I love you
# Predicted Translation: 我爱你是你是愛你。
# '我爱你是你是愛你。'

# %%
translate(new_transformer, 'did you finish your homework?')
# Out:
# Input: did you finish your homework?
# Predicted Translation: 你打著作业了嗎？
# '你打著作业了嗎？'

# %%
translate(new_transformer, 'what did you eat for breakfast?')
# Out:
# Input: what did you eat for breakfast?
# Predicted Translation: “一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个
# '“一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个一个'

# %%
translate(new_transformer, 'i am hungry right now')
# Out:
# Input: i am hungry right now
# Predicted Translation: 我現在是饿了。
# '我現在是饿了。'

# %%
# del en_val[36]
# # del chi_val[36]
# del en_val[122]
# del chi_val[122]

# %%
len(en_val)
# Out:
# 498

# %%
pynlpir.open()
bleuplus = 0
i = 0

for en_, chi_ in zip(en_val,chi_val):
    print(i)
    predicted = translate(new_transformer, en_)
    two_ = pynlpir.segment(predicted, pos_tagging=False)
    one_ = pynlpir.segment(chi_, pos_tagging=False)
    print('Real Translation: {}'.format(chi_))
    bleu_ = bleu.sentence_bleu([one_], two_)
    print("BLEU Score: ", bleu_)
    print("----" *20)

    bleuplus += bleu_
    i += 1
# Out:
# 0
# Input: what would you do if you had ten thousand dollars ?
# Predicted Translation: 如果我个二里做什麼的?
# Real Translation: 如果你有一万美元，你想做什么呢？
# BLEU Score:  9.97486269044271e-232
# --------------------------------------------------------------------------------
# 1
# Input: when i hear that song , i remember my younger days .
# Predicted Translation: 我在这首歌，深歌。
# Real Translation: 每次听到这首歌，都会让我回忆起自己年轻的时候。
# BLEU Score:  0.12151662434083678
# --------------------------------------------------------------------------------
# 2
# Input: when was the last time you spent time on facebook ?
# Predicted Translation: 在用用用用用用用用�上在Facebook在Facebook在Facebook在Facebook在Facebook在Facebook在Facebook在Facebook在Facebook在Facebook在Facebook在Facebook在Facebook在Facebook
# Real Translation: 你上一次用Facebook是什麼時候？
# BLEU Score:  8.726094729337945e-232
# --------------------------------------------------------------------------------
# 3
# Input: you are no better at remembering things than i am .
# Predicted Translation: 你羾������������������������������������
# Real Translation: 你记事情的能力并不比我好多少。
# BLEU Score:  6.891988818303256e-233
# --------------------------------------------------------------------------------
# 4
# Input: you don t seem to be as afraid as tom seems to be .
# Predicted Translation: 你看开始的那样害怕。
# Real Translation: 你似乎并不像汤姆看起来那样害怕
# BLEU Score:  5.795035077445241e-155
# --------------------------------------------------------------------------------
# 5
# Input: you look the way your father did thirty years ago .
# Predicted Translation: 你和他的父親的那次。
# Real Translation: 你看上去就像是三十年前你父親的樣子。
# BLEU Score:  2.5430549402662223e-78
# --------------------------------------------------------------------------------
# 6
# Input: you should be careful not to become overconfident .
# Predicted Translation: 你不该��在这�这唔�����������������������������
# Real Translation: 你要注意不要太自信。
# BLEU Score:  1.0832677820940877e-231
# --------------------------------------------------------------------------------
# 7
# Input: you should know better than to ask a lady her age .
# Predicted Translation: 你应该从从她壣�的。
# Real Translation: 你應該知道不要問小姐的年齡。
# BLEU Score:  7.813508425061864e-232
# --------------------------------------------------------------------------------
# 8
# Input: you should read a lot of books while you re young .
# Predicted Translation: 你应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该
# Real Translation: 當你年輕的時候, 你應該多讀點兒書。
# BLEU Score:  7.244248269687037e-232
# --------------------------------------------------------------------------------
# 9
# Input: you should read a lot of books while you re young .
# Predicted Translation: 你应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该应该
# Real Translation: 应该趁年轻多读点书。
# BLEU Score:  7.244248269687037e-232
# --------------------------------------------------------------------------------
# 10
# Input: you shouldn t talk back to your parents like that .
# Predicted Translation: 你寯������������������������������������
# Real Translation: 你不應該對你父母那樣頂嘴。
# BLEU Score:  6.891988818303256e-233
# --------------------------------------------------------------------------------
# 11
# Input: you want to be excused from doing that , don t you ?
# Predicted Translation: 你你你做的理由，不是麼？
# Real Translation: 你想通过做那件事而得到原谅是吗？
# BLEU Score:  9.988500430528834e-232
# --------------------------------------------------------------------------------
# 12
# Input: you d better go to see your family doctor at once .
# Predicted Translation: 你最好到家，马医生的。
# Real Translation: 你最好立刻去看你的家庭醫生。
# BLEU Score:  3.432765109268027e-78
# --------------------------------------------------------------------------------
# 13
# Input: you ll find it difficult to meet her requirements .
# Predicted Translation: 你的倪��的强是不费是不是不是不是不是不是不是不是不是不是不是不是不是不是不是不是不是不是不是不是不是不是不是不是不是不是不是不是不是不
# Real Translation: 你会发现难以满足她。
# BLEU Score:  6.3917876705550364e-232
# --------------------------------------------------------------------------------
# 14
# Input: you re working too hard . take it easy for a while .
# Predicted Translation: 你工作你工作你工作你工作這個壣�來。
# Real Translation: 你工作太勤奋了。休息一会吧。
# BLEU Score:  5.554837769749797e-155
# --------------------------------------------------------------------------------
# 15
# Input: have you seen my cell phone ? it s on the table .
# Predicted Translation: 你見了我看見了吗。”
# Real Translation: "你有看到我的手機嗎?" "它在桌子上。"
# BLEU Score:  5.481805263404418e-232
# --------------------------------------------------------------------------------
# 16
# Input: where have you been ? i ve been to the barber s .
# Predicted Translation: 咱店去了三裡处。
# Real Translation: 你去哪儿了？我去了理发店。
# BLEU Score:  5.588971591971542e-155
# --------------------------------------------------------------------------------
# 17
# Input: academic fraud is more common than you might think .
# Predicted Translation: 它的的的外是是是的外是外外外外外外外外外外外外外外外外外外外外外外外外外外外外外
# Real Translation: 学术造假比你想象的普遍。
# BLEU Score:  7.244248269687037e-232
# --------------------------------------------------------------------------------
# 18
# Input: all of us would like to get rid of nuclear weapons .
# Predicted Translation: 我们都想们这法这法这这法對们法對们法對们法對们法對们法對们對们對们法對们法對们法對
# Real Translation: 我們所有的人都想除掉核子武器。
# BLEU Score:  2.8225949814960253e-155
# --------------------------------------------------------------------------------
# 19
# Input: all you have to do is say the word , and i ll leave .
# Predicted Translation: 你必須，，，你要说了就是那那那那那那那那那那那那那那那那那那那那那那那那那那那那那那那那
# Real Translation: 你只要说句话，我就走。
# BLEU Score:  1.2882297539194154e-231
# --------------------------------------------------------------------------------
# 20
# Input: are you saying you don t want to go to tom s party ?
# Predicted Translation: 你说汤姆的那們动他的车
# Real Translation: 你的意思是你不想去汤姆的派对？
# BLEU Score:  5.607479438626032e-155
# --------------------------------------------------------------------------------
# 21
# Input: as far as i m concerned , she s a complete stranger .
# Predicted Translation: ，，她情，她，她，她，她，她，她，她，她，她是一个是一个是一个是一个是一个是一个後，她，她，她是一个是一个是一个
# Real Translation: 她对我来说是一个完全陌生的人。
# BLEU Score:  2.878979728837258e-155
# --------------------------------------------------------------------------------
# 22
# Input: as far as i m concerned , this coffee is too strong .
# Predicted Translation: 我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我
# Real Translation: 这咖啡对我来说太浓了。
# BLEU Score:  7.244248269687037e-232
# --------------------------------------------------------------------------------
# 23
# Input: as soon as he sat down , he picked up the telephone .
# Predicted Translation: 就就就就就就就就就就就就就就就就就就就就就就就就就就就就就就就就就就就就就就就就
# Real Translation: 他一坐下，就拿起了電話。
# BLEU Score:  7.244248269687037e-232
# --------------------------------------------------------------------------------
# 24
# Input: because his salary is low , he can t buy that house .
# Predicted Translation: 这工作，所以建那小孩家。
# Real Translation: 因為他的薪水太低，他買不起那棟房子。
# BLEU Score:  6.3597993332323924e-232
# --------------------------------------------------------------------------------
# 25
# Input: can you imagine what the st century will be like ?
# Predicted Translation: 你可以想�怎么样是排裡裡裡裡裡裡裡裡裡裡裡裡裡裡裡裡裡裡裡裡裡裡裡裡裡？
# Real Translation: 你能想象21世紀會是甚麼樣嗎？
# BLEU Score:  1.0080942617254966e-231
# --------------------------------------------------------------------------------
# 26
# Input: china is about twenty five times as large as japan .
# Predicted Translation: 和日本和日本一樣那個。
# Real Translation: 中国的版图大概是日本的二十五倍。
# BLEU Score:  1.1193096620723278e-231
# --------------------------------------------------------------------------------
# 27
# Input: do not fear the unexpected , but be prepared for it .
# Predicted Translation: 别這豬，这怕��������������������������������
# Real Translation: 不要害怕意外，但要有準備。
# BLEU Score:  7.296382734947757e-232
# --------------------------------------------------------------------------------
# 28
# Input: don t speak unless you have something worth saying .
# Predicted Translation: 别边說，有有人說。
# Real Translation: 除非你有什么值得说的话要说，否则就别吭声。
# BLEU Score:  5.635809992474887e-232
# --------------------------------------------------------------------------------
# 29
# Input: driving on a slippery road can lead to a car wreck .
# Predicted Translation: 開車會恶在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在
# Real Translation: 在光滑的路上开车会导致车祸。
# BLEU Score:  7.199666163340923e-232
# --------------------------------------------------------------------------------
# 30
# Input: elephants are the largest land animals alive today .
# Predicted Translation: 大象们最大的动物。
# Real Translation: 大象是如今现存的陆生动物里最大的。
# BLEU Score:  2.534102530743338e-78
# --------------------------------------------------------------------------------
# 31
# Input: everybody in the room was stunned by what happened .
# Predicted Translation: 沒有人聚一遍一遍倒了。
# Real Translation: 屋裡的每個人都被發生的事驚住了。
# BLEU Score:  3.8476696299631795e-155
# --------------------------------------------------------------------------------
# 32
# Input: everyone except tom knew he didn t need to do that .
# Predicted Translation: 除了除了每个人都，除了除了。
# Real Translation: 除了汤姆以外任何人都知道他没必要这么做。
# BLEU Score:  9.918892480173173e-232
# --------------------------------------------------------------------------------
# 33
# Input: everyone ought to be the master of his own destiny .
# Predicted Translation: 每個人都应该命的主人。
# Real Translation: 每個人都應該做自己命運的主人。
# BLEU Score:  0.28617394805234075
# --------------------------------------------------------------------------------
# 34
# Input: for some reason the microphone didn t work earlier .
# Predicted Translation: 在的個�台沒有沒有开台機機機機機機機機機機機機機機機機機機機機機機機機機機機機機機
# Real Translation: 剛才我的麥克風沒起作用，不知道為什麼。
# BLEU Score:  8.614911585158347e-232
# --------------------------------------------------------------------------------
# 35
# Input: he has no right to interfere in our family affairs .
# Predicted Translation: 他不法來我裡關�利。
# Real Translation: 他无权干涉我们的家庭事务。
# BLEU Score:  1.2882297539194154e-231
# --------------------------------------------------------------------------------
# 36
# Input: he postponed leaving for hokkaido until next month .
# Predicted Translation: 他將在北海道開的月開常�����������������������������
# Real Translation: 他延遲到下個月去北海道。
# BLEU Score:  1.3483065280626046e-231
# --------------------------------------------------------------------------------
# 37
# Input: he said he did not enter the room , which was a lie .
# Predicted Translation: 他是他是他是他是假, 他是用這个房間。
# Real Translation: 他说他没有进房间，那是骗人的。
# BLEU Score:  1.2340561512781763e-231
# --------------------------------------------------------------------------------
# 38
# Input: he went to italy for the purpose of studying music .
# Predicted Translation: 他他到學習音樂。
# Real Translation: 他去義大利的目的是學習音樂。
# BLEU Score:  0.2896204682801084
# --------------------------------------------------------------------------------
# 39
# Input: he s getting along well with all of his classmates .
# Predicted Translation: 他和他的他的他的相處。
# Real Translation: 他和他所有的同学相处融洽。
# BLEU Score:  3.8719283242189536e-78
# --------------------------------------------------------------------------------
# 40
# Input: her parents can t help worrying about her injuries .
# Predicted Translation: 我父母沒有以她失喃的。
# Real Translation: 她的父母不能不担心她的伤势。
# BLEU Score:  1.4488496539373276e-231
# --------------------------------------------------------------------------------
# 41
# Input: how long has it been since you saw your girlfriend ?
# Predicted Translation: 从深深深深的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的
# Real Translation: 你跟你的女朋友见面以来有多久了？
# BLEU Score:  7.337741777064293e-232
# --------------------------------------------------------------------------------
# 42
# Input: how many different kinds of pizzas are on the menu ?
# Predicted Translation: 这個什麼有任何一場。
# Real Translation: 菜單上有多少種比薩？
# BLEU Score:  1.0518351895246305e-231
# --------------------------------------------------------------------------------
# 43
# Input: i am surprised that your family has a japanese car .
# Predicted Translation: 很家人有日本。
# Real Translation: 我很惊讶，你家居然有辆日本车。
# BLEU Score:  7.154403670282264e-232
# --------------------------------------------------------------------------------
# 44
# Input: i couldn t prevent tom from eating all the cookies .
# Predicted Translation: 我不能這裡做了湯姆都在所有蛋糕都在痪�。
# Real Translation: 我阻止不了汤姆把饼干全吃了。
# BLEU Score:  1.0832677820940877e-231
# --------------------------------------------------------------------------------
# 45
# Input: i discovered that speaking english was pretty easy .
# Predicted Translation: 我对地地覺容易很容易。
# Real Translation: 我發覺說英語很簡單。
# BLEU Score:  1.331091014027761e-231
# --------------------------------------------------------------------------------
# 46
# Input: i don t even want to think about what could happen .
# Predicted Translation: 我甚至甚至不想想。
# Real Translation: 我甚至不想去想會發生什麼。
# BLEU Score:  3.2351101051816727e-78
# --------------------------------------------------------------------------------
# 47
# Input: i don t use taxis unless it s absolutely necessary .
# Predicted Translation: 不用时候，我来需要需要车的。
# Real Translation: 如无必要我也不会打的。
# BLEU Score:  6.513869329968086e-155
# --------------------------------------------------------------------------------
# 48
# Input: i find it difficult to express my meaning in words .
# Predicted Translation: 我詞不理解自己的略。
# Real Translation: 我覺得很難用言語表達我的意思。
# BLEU Score:  6.734343721752972e-232
# --------------------------------------------------------------------------------
# 49
# Input: i go to the office by bicycle except on rainy days .
# Predicted Translation: 此日，我的日是月上班。
# Real Translation: 除了雨天，我都是骑车去上班的。
# BLEU Score:  6.858354866987037e-155
# --------------------------------------------------------------------------------
# 50
# Input: i like rugby , but not as much as i like basketball .
# Predicted Translation: 我喜歡，但我不喜欢籃球。
# Real Translation: 我喜欢橄榄球，但不像我喜欢篮球那么喜欢。
# BLEU Score:  6.246488163223622e-155
# --------------------------------------------------------------------------------
# 51
# Input: i think a movie is more entertaining than any book .
# Predicted Translation: 我认为一部一电影的大过。
# Real Translation: 我觉得一部电影比任何书都有趣。
# BLEU Score:  6.552765724042392e-155
# --------------------------------------------------------------------------------
# 52
# Input: i think a movie is more entertaining than any book .
# Predicted Translation: 我认为一部一电影的大过。
# Real Translation: 我认为一部电影的乐趣远胜于任何一本书。
# BLEU Score:  0.20360578738768487
# --------------------------------------------------------------------------------
# 53
# Input: i thought i told you to stay away from my computer .
# Predicted Translation: 我告诉你�裏不是真的匮�。
# Real Translation: 我说过让你离我的电脑远一点的。
# BLEU Score:  9.988500430528834e-232
# --------------------------------------------------------------------------------
# 54
# Input: i understand that you feel uneasy , but don t worry .
# Predicted Translation: 我知道你担心，没什么感到担心。
# Real Translation: 我知道你不自在，但别急。
# BLEU Score:  4.101791032784236e-78
# --------------------------------------------------------------------------------
# 55
# Input: i want a boat that will take me far away from here .
# Predicted Translation: 这的的船的不離開。
# Real Translation: 我想要一艘船带我远离这里。
# BLEU Score:  1.0016022933125248e-231
# --------------------------------------------------------------------------------
# 56
# Input: i wanted to ask tom how long he had lived in india .
# Predicted Translation: 想想想汤姆在為甚麼湯姆夥及时间。
# Real Translation: 我想问汤姆他在印度生活了多久。
# BLEU Score:  1.2627076138080564e-231
# --------------------------------------------------------------------------------
# 57
# Input: i was wondering if you were going to show up today .
# Predicted Translation: 我今天想你是否出現來來來來來來來來來來來來來來來來來來來來來來來來來來來來來來來來來來來
# Real Translation: 我在想你今天会不会来。
# BLEU Score:  3.2747558509437065e-155
# --------------------------------------------------------------------------------
# 58
# Input: i wouldn t ask this of you if it weren t important .
# Predicted Translation: 我如果，你不是個個個個個個個個個個個個個個個個個個個個個個個個個個個個個個個個個個個
# Real Translation: 如果不是它很重要，我不會問你。
# BLEU Score:  3.6685890571305766e-155
# --------------------------------------------------------------------------------
# 59
# Input: i d like to exchange this shirt i bought yesterday .
# Predicted Translation: 我想想昨天的襯衫。
# Real Translation: 我想去換我昨天買的這件襯衫。
# BLEU Score:  3.2686774053939754e-78
# --------------------------------------------------------------------------------
# 60
# Input: i ll only buy the car if they fix the brakes first .
# Predicted Translation: 我刷�的，我会賣車子的車。
# Real Translation: 除非他们事先修好刹车，我才会买车子。
# BLEU Score:  1.2021513525930774e-231
# --------------------------------------------------------------------------------
# 61
# Input: i m disappointed that i wasn t able to go with her .
# Predicted Translation: 我是我考试沒和他了。
# Real Translation: 我很失望我沒能和她一起去。
# BLEU Score:  1.2594482068582575e-231
# --------------------------------------------------------------------------------
# 62
# Input: i m on my way to meet tom at the station right now .
# Predicted Translation: 我这在汤姆的路的。
# Real Translation: 我现在在去车站见汤姆的路上。
# BLEU Score:  6.3502977614349235e-155
# --------------------------------------------------------------------------------
# 63
# Input: i ve been told that you re a very competent person .
# Predicted Translation: 你說有一個厎师。
# Real Translation: 有人說你是個很有能力的人。
# BLEU Score:  7.154403670282264e-232
# --------------------------------------------------------------------------------
# 64
# Input: i ve done bad things that i should be punished for .
# Predicted Translation: 我我有个事沒做种事情的事。
# Real Translation: 我做了該受罰的壞事。
# BLEU Score:  6.5806869883189804e-155
# --------------------------------------------------------------------------------
# 65
# Input: if there was no sun , all the animals would be dead .
# Predicted Translation: 在動物，我都，我都，我都，我都，我都，我都，我都，我都，我都，我都，我都，我都，我都，我都，我都，我都，我都，我都，我都
# Real Translation: 如果没有太阳，那所有生物都会死。
# BLEU Score:  7.784451369270533e-232
# --------------------------------------------------------------------------------
# 66
# Input: if you can t have children , you could always adopt .
# Predicted Translation: 如果你不事，无法養孩子。
# Real Translation: 如果你不能有孩子，你总能领养。
# BLEU Score:  3.4376286321877657e-78
# --------------------------------------------------------------------------------
# 67
# Input: is it true that tom wants to paint his house green ?
# Predicted Translation: 汤姆是湯姆不想六改吗？
# Real Translation: 汤姆想把房子漆成绿色，是真的吗？
# BLEU Score:  5.364950815988815e-155
# --------------------------------------------------------------------------------
# 68
# Input: it is believed that whales have their own language .
# Predicted Translation: 人们人们有一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条
# Real Translation: 人们相信鲸有他们自己的语言。
# BLEU Score:  7.31380102804205e-232
# --------------------------------------------------------------------------------
# 69
# Input: it is impossible to master english in a short time .
# Predicted Translation: 在攔������������������������������������
# Real Translation: 不可能短时间内学会英语。
# BLEU Score:  0
# --------------------------------------------------------------------------------
# 70
# Input: it isn t anything like as cold as it was yesterday .
# Predicted Translation: 從日如月一樣一樣一樣一樣一樣一樣一樣一樣一樣一樣一樣一樣一樣的。
# Real Translation: 今天沒有像昨天那麼冷。
# BLEU Score:  7.659859945595747e-232
# --------------------------------------------------------------------------------
# 71
# Input: it took a long time to take in what she was saying .
# Predicted Translation: 她从時間很長剕������������������
# Real Translation: 花了很久才能听懂她在说什么。
# BLEU Score:  6.895396983435736e-232
# --------------------------------------------------------------------------------
# 72
# Input: it will be snowing when we arrive at shiga heights .
# Predicted Translation: 在月是在山兖��������������������������������
# Real Translation: 我们到达志贺高原时会下雪。
# BLEU Score:  0
# --------------------------------------------------------------------------------
# 73
# Input: it would take forever for me to explain everything .
# Predicted Translation: 長让我让我會甔��的�的�的�的�的�的�的�的�的�的�的�的�的�的�的
# Real Translation: 要都解释的话，需要一辈子的时间。
# BLEU Score:  0
# --------------------------------------------------------------------------------
# 74
# Input: it s been a long time since we last saw each other .
# Predicted Translation: 后彼此有久有久有久有久有久有久有久有久有久有久有久有久有久有久有久有久有久有久有久
# Real Translation: 真是好久不见啊
# BLEU Score:  7.244248269687037e-232
# --------------------------------------------------------------------------------
# 75
# Input: it s been hot this month , but today s an exception .
# Predicted Translation: 这月月的月，我們是熱的。
# Real Translation: 这个月一直都很热，但今天是个例外。
# BLEU Score:  1.1795395762188e-231
# --------------------------------------------------------------------------------
# 76
# Input: it s fun to learn slang words in foreign languages .
# Predicted Translation: 来講外一語很語。
# Real Translation: 学习外语里的俚语很有趣。
# BLEU Score:  1.2882297539194154e-231
# --------------------------------------------------------------------------------
# 77
# Input: let go of my arm ! i can t stand people touching me .
# Predicted Translation: 帶著有人不在人不在人都在這裡。
# Real Translation: 放開我的手臂！我不能忍受有人碰我。
# BLEU Score:  1.1008876702055895e-231
# --------------------------------------------------------------------------------
# 78
# Input: life in prison is worse than the life of an animal .
# Predicted Translation: 在監獄是�是动物。
# Real Translation: 监狱生活比做畜牲还不如。
# BLEU Score:  8.416851712392762e-232
# --------------------------------------------------------------------------------
# 79
# Input: many schools are closed today because of the storm .
# Predicted Translation: 許多個個暴風個暴風個暴風暴風暴風暴風暴風暴風暴風暴風暴風暴風暴風暴風暴風個暴風暴風物都被行了。
# Real Translation: 今天许多学校因为风暴停课。
# BLEU Score:  6.957990942521506e-232
# --------------------------------------------------------------------------------
# 80
# Input: many young people in japan eat bread for breakfast .
# Predicted Translation: 在日本的时候的时候在日本，在日本在日本在日本在日本在日本在日本在日本在日本在日本在日本在日本在日本在日本在日本在日本在日本在
# Real Translation: 許多日本的年輕人吃麵包當作早餐。
# BLEU Score:  2.753730455889728e-155
# --------------------------------------------------------------------------------
# 81
# Input: mary has as attractive a personality as her sister .
# Predicted Translation: 玛丽表和她一樣漂亮。
# Real Translation: 玛丽性格很好，就像她姐姐一样。
# BLEU Score:  9.798412298238562e-232
# --------------------------------------------------------------------------------
# 82
# Input: mercury is the smallest planet in our solar system .
# Predicted Translation: 許多星裡中的顆地小地地地地地地地地地地地地地地地地地地地地地地地地地地地地地地地地地
# Real Translation: 水星是我們的太陽系中最小的行星。
# BLEU Score:  9.418382295637229e-232
# --------------------------------------------------------------------------------
# 83
# Input: more money for education will spur economic growth .
# Predicted Translation: 这錢能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能
# Real Translation: 更多投資在教育的錢將會刺激經濟成長。
# BLEU Score:  7.244248269687037e-232
# --------------------------------------------------------------------------------
# 84
# Input: one of the main products of this country is coffee .
# Predicted Translation: 这个位是位是�是寫是咖啡。
# Real Translation: 这个国家的主要产品之一是咖啡。
# BLEU Score:  3.965294799986402e-78
# --------------------------------------------------------------------------------
# 85
# Input: people can easily tell the difference between them .
# Predicted Translation: 人能说在一分相相在同在同在同中。
# Real Translation: 人們可以很容易地看出其中的差別。
# BLEU Score:  1.1008876702055895e-231
# --------------------------------------------------------------------------------
# 86
# Input: please wait for me at the entrance of the building .
# Predicted Translation: 在在在楼的楼。
# Real Translation: 请在建筑的入口处等我。
# BLEU Score:  1.2778269941762074e-231
# --------------------------------------------------------------------------------
# 87
# Input: please write to me about conditions at your school .
# Predicted Translation: 請你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的
# Real Translation: 请写信告诉我你们学校的情况。
# BLEU Score:  6.110848977001762e-232
# --------------------------------------------------------------------------------
# 88
# Input: president lincoln was what we call a self made man .
# Predicted Translation: 䚚�������������������������������������
# Real Translation: 林肯總統就是我們所謂白手起家的男人。
# BLEU Score:  0
# --------------------------------------------------------------------------------
# 89
# Input: research on the causes of cancer is very expensive .
# Predicted Translation: 在观的�的莎�������的莎������的莎������的莎
# Real Translation: 有關癌症成因的研究耗費頗巨。
# BLEU Score:  1.0003688322288243e-231
# --------------------------------------------------------------------------------
# 90
# Input: she can sing better than anybody else in her class .
# Predicted Translation: 她班上在她胜好。
# Real Translation: 她唱歌唱得比班上任何一個人好。
# BLEU Score:  5.190284426706258e-155
# --------------------------------------------------------------------------------
# 91
# Input: she twisted her ankle while she was doing exercise .
# Predicted Translation: 她在着着着着着着着着着着着着着着着着着着着着着着着着着着着着着着着着着着着着着着着
# Real Translation: 她锻炼时扭伤了脚踝。
# BLEU Score:  7.199666163340923e-232
# --------------------------------------------------------------------------------
# 92
# Input: she was at a loss for words to express her feeling .
# Predicted Translation: 她難滻的。
# Real Translation: 她已经无法用语言表达她的感觉了。
# BLEU Score:  4.829395330616745e-232
# --------------------------------------------------------------------------------
# 93
# Input: she wrote him a long letter , but he didn t read it .
# Predicted Translation: 她封信，他读了廤�������������������������������
# Real Translation: 她给他写了一封长信，但是他没有看。
# BLEU Score:  4.11478596261685e-155
# --------------------------------------------------------------------------------
# 94
# Input: stop getting yourself worked up over little things .
# Predicted Translation: 记事情在一切吵心。
# Real Translation: 不要让自己因为一些小事而烦躁了。
# BLEU Score:  7.296382734947757e-232
# --------------------------------------------------------------------------------
# 95
# Input: stop getting yourself worked up over little things .
# Predicted Translation: 记事情在一切吵心。
# Real Translation: 不要让自己因为一些小事就方寸大乱了。
# BLEU Score:  5.483065946899793e-232
# --------------------------------------------------------------------------------
# 96
# Input: thanks for accepting my friend request on facebook .
# Predicted Translation: 用用用�在你的號的在這裡的的的的的的的的。
# Real Translation: 謝謝你接受我Facebook的交友邀請。
# BLEU Score:  1.1337861261109773e-231
# --------------------------------------------------------------------------------
# 97
# Input: that child may have been kidnapped on his way home .
# Predicted Translation: 那孩子可能一個小行李。
# Real Translation: 那个孩子可能在回家的路上被绑架了。
# BLEU Score:  4.677275655524805e-155
# --------------------------------------------------------------------------------
# 98
# Input: that was the first time that i d seen tom so angry .
# Predicted Translation: 難來聚覺得湯姆不說話。
# Real Translation: 那是我第一次见到汤姆如此生气。
# BLEU Score:  1.0003688322288243e-231
# --------------------------------------------------------------------------------
# 99
# Input: the amazon is fed by a large number of tributaries .
# Predicted Translation: 入入入入多流用多多多多多多多多多多多多多多多多多多多多多多多多多多多多多多多多多
# Real Translation: 亚马逊河有很多支流。
# BLEU Score:  0
# --------------------------------------------------------------------------------
# 100
# Input: the cold war ended when the soviet union collapsed .
# Predicted Translation: 大大大大大大大大大大大大大大大大大大大大大大大大大大大大大大大大大大大大大大大大
# Real Translation: 冷战以苏联解体结束。
# BLEU Score:  0
# --------------------------------------------------------------------------------
# 101
# Input: the united states is abundant in natural resources .
# Predicted Translation: 許多的洲的富的富的富的富的富的富的富的富的富的富的富的富的富的富的富的富的富的富的
# Real Translation: 美国的自然资源很丰富。
# BLEU Score:  7.199666163340923e-232
# --------------------------------------------------------------------------------
# 102
# Input: the equator divides the globe into two hemispheres .
# Predicted Translation: 这垌������������������������������������
# Real Translation: 赤道把地球分为两个半球。
# BLEU Score:  0
# --------------------------------------------------------------------------------
# 103
# Input: the job looked quite simple , but it took me a week .
# Predicted Translation: 一的工作，深的深的深的深的深的深的深的深的深的深的深的深的深的深的深的深的深的深的
# Real Translation: 這份工作看起來很簡單，但它花了我一個星期。
# BLEU Score:  9.533966891110756e-232
# --------------------------------------------------------------------------------
# 104
# Input: the people of london are very proud of this bridge .
# Predicted Translation: 一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条一条
# Real Translation: 倫敦人對這座橋感到非常自豪。
# BLEU Score:  0
# --------------------------------------------------------------------------------
# 105
# Input: the physician prescribed his patient some medicine .
# Predicted Translation: 医生这些藥地了。
# Real Translation: 医生给他的病人开了一些药。
# BLEU Score:  7.865406450922293e-232
# --------------------------------------------------------------------------------
# 106
# Input: the police assembled a lot of evidence against him .
# Predicted Translation: 警方盘了他晕��������������������了。
# Real Translation: 警察收集了很多对他不利的证据。
# BLEU Score:  9.602579706020654e-232
# --------------------------------------------------------------------------------
# 107
# Input: the sky today is the bluest that i ve ever seen it .
# Predicted Translation: 今天今天們是是是是是是天的。
# Real Translation: 今天的天空是我看過最藍的天空。
# BLEU Score:  1.384292958842266e-231
# --------------------------------------------------------------------------------
# 108
# Input: the teacher granted me permission to go home early .
# Predicted Translation: 老師的老師，我很早很开始。
# Real Translation: 老師允許我提前回家。
# BLEU Score:  6.223629500679345e-155
# --------------------------------------------------------------------------------
# 109
# Input: the things he says are not the least bit important .
# Predicted Translation: 他說的話，他不重要重要重要重要重要重要重要重要重要重要重要重要重要重要重要重要重要重要重要重要重要重要重要重要重要重要重要重要重要重要重要重要重要重要重要重要重要
# Real Translation: 他说的话根本毫无意义。
# BLEU Score:  8.412065649527267e-232
# --------------------------------------------------------------------------------
# 110
# Input: the truth is that nothing is totally true or false .
# Predicted Translation: 这么基的话就是基件事就是是是是是是是是是是是是是是是是是是是是是是是是是是是是是是是是
# Real Translation: 真相是沒有甚麼完全正確或錯誤。
# BLEU Score:  7.244248269687037e-232
# --------------------------------------------------------------------------------
# 111
# Input: the weather forecast says it will be fine tomorrow .
# Predicted Translation: 明天的天氣很好。
# Real Translation: 根據氣象預報，明天會是晴天。
# BLEU Score:  7.216120604020078e-232
# --------------------------------------------------------------------------------
# 112
# Input: there is a castle in the background of the picture .
# Predicted Translation: 這張這張這張這張美麗的畫的上的美麗的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的
# Real Translation: 图片的背景是一座城堡。
# BLEU Score:  6.885877678021066e-232
# --------------------------------------------------------------------------------
# 113
# Input: there s a bottle of white wine in the refrigerator .
# Predicted Translation: 對瓶酒里有酒。
# Real Translation: 冰箱里有一瓶白葡萄酒。
# BLEU Score:  8.286571670851008e-155
# --------------------------------------------------------------------------------
# 114
# Input: they set fire to their neighbor s house in revenge .
# Predicted Translation: 他們他們他們住在一個一個房子家。
# Real Translation: 為了報仇，他們放火燒了鄰居的家。
# BLEU Score:  6.5900678916581e-155
# --------------------------------------------------------------------------------
# 115
# Input: this company is listed on the paris stock exchange .
# Predicted Translation: 这个场的�的。
# Real Translation: 这家公司在巴黎证券交易所上市了。
# BLEU Score:  5.474320712955125e-232
# --------------------------------------------------------------------------------
# 116
# Input: this guidebook might be of use to you on your trip .
# Predicted Translation: 这的的的旅行的。
# Real Translation: 这本导游册子或许会对你的旅行有帮助。
# BLEU Score:  3.5165960008650403e-155
# --------------------------------------------------------------------------------
# 117
# Input: to the best of my knowledge , the rumor is not true .
# Predicted Translation: 䣣�������������������������������������
# Real Translation: 据我所知，这个谣言不是真的。
# BLEU Score:  0
# --------------------------------------------------------------------------------
# 118
# Input: tom can t decide whether to buy a toyota or a ford .
# Predicted Translation: 湯姆不法给車子，比开开开开开开开开开开开开开开开开开开开开开开开开开开开开开开开开开开
# Real Translation: 汤姆不能决定买丰田还是福特。
# BLEU Score:  0
# --------------------------------------------------------------------------------
# 119
# Input: tom didn t think that anybody would recognize mary .
# Predicted Translation: 汤姆甚麼也也不會也不對玛丽也不會也不也不也不也不也不也不也不也不也不也不也不也不也不也不也不也不也不也不也不也不也不也不也不也不也不也不也不也不也不也不也不
# Real Translation: 汤姆不认为有人会认出玛丽。
# BLEU Score:  8.120546156106983e-232
# --------------------------------------------------------------------------------
# 120
# Input: tom is from australia and mary is from new zealand .
# Predicted Translation: 汤姆在玛丽自玛丽西西西西西西西西西西西西西西西西西西西西西西西西西西西西西西西西西西西西
# Real Translation: 汤姆来自澳大利亚，玛丽来自新西兰。
# BLEU Score:  9.893133360884868e-232
# --------------------------------------------------------------------------------
# 121
# Input: tom knows that i want to leave as soon as possible .
# Predicted Translation: 汤姆我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我
# Real Translation: 湯姆知道我想盡早離開。
# BLEU Score:  7.244248269687037e-232
# --------------------------------------------------------------------------------
# 122
# Input: tom probably knows someone who can teach us french .
# Predicted Translation: 汤姆可能所懂法语。
# Real Translation: 湯姆應該知道有誰可以教我們法文。
# BLEU Score:  3.624879844624495e-232
# --------------------------------------------------------------------------------
# 123
# Input: tom says that mary definitely won t accept the job .
# Predicted Translation: 汤姆在玛丽不想玛丽說。
# Real Translation: 湯姆說瑪麗絕不會接受這工作。
# BLEU Score:  8.647068503442337e-232
# --------------------------------------------------------------------------------
# 124
# Input: tom told me that i shouldn t go out alone at night .
# Predicted Translation: 湯姆說我不告訴我我，我不一个人沒一个人沒一个人。
# Real Translation: 汤姆跟我说我不应该晚上一个人出门。
# BLEU Score:  6.13274920178966e-155
# --------------------------------------------------------------------------------
# 125
# Input: tom told me that he doesn t like carbonated drinks .
# Predicted Translation: 湯姆說我说看喝酒。
# Real Translation: 汤姆告诉我他不喜欢碳酸饮料。
# BLEU Score:  1.1368587676511996e-231
# --------------------------------------------------------------------------------
# 126
# Input: tom very often takes a nap for an hour after lunch .
# Predicted Translation: 汤姆在清后睡睡。
# Real Translation: 汤姆很经常在午饭后小憩一小时。
# BLEU Score:  1.0318643420027732e-231
# --------------------------------------------------------------------------------
# 127
# Input: tom was advised by mary not to go there by himself .
# Predicted Translation: 汤姆被對對對玛丽該得不獨想去那裡。
# Real Translation: 玛丽建议汤姆不要独自去。
# BLEU Score:  1.3091834502273125e-231
# --------------------------------------------------------------------------------
# 128
# Input: up to now , how many books do you think you ve read ?
# Predicted Translation: 你现在多多少书，不是嗎？
# Real Translation: 到目前为止，你认为你阅读过多少书籍？
# BLEU Score:  1.0658543616184898e-231
# --------------------------------------------------------------------------------
# 129
# Input: visiting all the tourist sights really wore me out .
# Predicted Translation: 观地游�的�的的的的的的的的的的。
# Real Translation: 參觀所有觀光勝地累壞了我。
# BLEU Score:  1.1008876702055895e-231
# --------------------------------------------------------------------------------
# 130
# Input: water is liquid . when it freezes , it becomes solid .
# Predicted Translation: 水结体，我们廟，我们���������������
# Real Translation: 水是液体。冻起来就成了固体。
# BLEU Score:  8.422437779564611e-232
# --------------------------------------------------------------------------------
# 131
# Input: we all wondered why she had dumped such a nice man .
# Predicted Translation: 我们都都想要那個男孩。
# Real Translation: 我們都想知道她為什麼甩了這麼好的一個男人。
# BLEU Score:  2.383991294021642e-155
# --------------------------------------------------------------------------------
# 132
# Input: when i entered the room , she was playing the piano .
# Predicted Translation: 我天，我在天彈鋼琴。
# Real Translation: 当我进入那个房间的时候，她正在弹钢琴。
# BLEU Score:  9.037968939610782e-232
# --------------------------------------------------------------------------------
# 133
# Input: with a little more effort , he would have succeeded .
# Predicted Translation: 他的有的向有有有有有有有有有有有有有有有有有有有有有有有有有有有有有有有有有有有
# Real Translation: 如果他当时再努力一点，他就成功了。
# BLEU Score:  7.290245807398516e-232
# --------------------------------------------------------------------------------
# 134
# Input: with her help , my french improved little by little .
# Predicted Translation: 我的我的我的我的我的我的我的我的我的我的我的我的我的我的我的我的我的我的我的我的我的我的我的我的我的我的我的我的我的我的我的我的我的我的我的我的我的我的我的我的
# Real Translation: 在她的帮助下，我的法语逐渐进步了。
# BLEU Score:  2.2017766405070104e-155
# --------------------------------------------------------------------------------
# 135
# Input: you are working too hard . take it easy for a while .
# Predicted Translation: 你工作你工作你工作你工作這個你工作。
# Real Translation: 你工作得太辛苦了。放輕鬆一下。
# BLEU Score:  5.554837769749797e-155
# --------------------------------------------------------------------------------
# 136
# Input: you can t buy this medicine without a prescription .
# Predicted Translation: 是你用药是药用這個药外药外药外药外药外药外药外药外药外药外药外药外药外药外药外药外药
# Real Translation: 那个药的话没有处方是买不到的。
# BLEU Score:  8.561894227089738e-232
# --------------------------------------------------------------------------------
# 137
# Input: you have to study hard to catch up with your class .
# Predicted Translation: 你太把头发活的。
# Real Translation: 你必須用功讀書趕上同學。
# BLEU Score:  7.521821744402224e-232
# --------------------------------------------------------------------------------
# 138
# Input: you must look over the contract before you sign it .
# Predicted Translation: 你该用文件前先文件签下。
# Real Translation: 你在签字前必须察看这合同。
# BLEU Score:  1.3483065280626046e-231
# --------------------------------------------------------------------------------
# 139
# Input: you ought to let tom know mary is going to do that .
# Predicted Translation: 你應該應該汤姆都去做。
# Real Translation: 你該讓湯姆知道瑪麗要去做。
# BLEU Score:  3.432765109268027e-78
# --------------------------------------------------------------------------------
# 140
# Input: you re the one who suggested that we sing together .
# Predicted Translation: “我们天們們們們們們們們們們們們們們們們們們們們們們們們們們們們們們們們們們們們們
# Real Translation: 你是那個建議我們一起唱歌的人。
# BLEU Score:  7.244248269687037e-232
# --------------------------------------------------------------------------------
# 141
# Input: you ve been late for school more often than before .
# Predicted Translation: 你常上學遲到。
# Real Translation: 你比以前更容易上課遲到了。
# BLEU Score:  4.948050447709567e-155
# --------------------------------------------------------------------------------
# 142
# Input: a beautiful woman was seated one row in front of me .
# Predicted Translation: 一個美美美面前的美人。
# Real Translation: 一個美麗的女人坐在我前面一排。
# BLEU Score:  4.909777631374571e-155
# --------------------------------------------------------------------------------
# 143
# Input: a caged cricket eats just as much as a free cricket .
# Predicted Translation: 對的剄�����������������������������������
# Real Translation: 籠子裡的蟋蟀吃得跟野生的蟋蟀一樣多。
# BLEU Score:  8.235377291091144e-233
# --------------------------------------------------------------------------------
# 144
# Input: a couch potato is something that i don t want to be .
# Predicted Translation: 我式个板是小孩。
# Real Translation: 我不想成為整天泡在沙發上看電視的人。
# BLEU Score:  3.192056898346732e-232
# --------------------------------------------------------------------------------
# 145
# Input: a drunk driver was responsible for the car accident .
# Predicted Translation: 酒酒是驾名。
# Real Translation: 喝醉的驾驶员对车祸有责任。
# BLEU Score:  7.060301868108111e-232
# --------------------------------------------------------------------------------
# 146
# Input: a fire broke out at the inn where they were staying .
# Predicted Translation: 在他們在火裡住在火碣。
# Real Translation: 火警發生在他們住的旅館。
# BLEU Score:  3.8719283242189536e-78
# --------------------------------------------------------------------------------
# 147
# Input: all of a sudden , three dogs appeared in front of us .
# Predicted Translation: 突然我们，我们大這裡。
# Real Translation: 突然之間，三隻狗出現在我們面前。
# BLEU Score:  6.734343721752972e-232
# --------------------------------------------------------------------------------
# 148
# Input: all of you are familiar with the truth of the story .
# Predicted Translation: 你們三個个事实。
# Real Translation: 你們所有的人都熟悉這個故事的真相。
# BLEU Score:  3.5165960008650403e-155
# --------------------------------------------------------------------------------
# 149
# Input: at last , she gave in to him and told him the secret .
# Predicted Translation: 最後帥�地之，她之口。
# Real Translation: 最後，她對他屈服了，並告訴了他這個秘密。
# BLEU Score:  3.869688464263088e-155
# --------------------------------------------------------------------------------
# 150
# Input: at that time , tom was sitting between mary and john .
# Predicted Translation: 這個同一裡在瑪麗翰之間翰之間翰裡裡裡裡裡裡裡裡裡裡裡裡裡裡裡裡裡裡裡裡裡裡裡裡裡裡裡裡裡裡
# Real Translation: 在那个时候，汤姆正坐在玛丽和约翰中间。
# BLEU Score:  8.412065649527267e-232
# --------------------------------------------------------------------------------
# 151
# Input: be sure to fill out the registration form in person .
# Predicted Translation: 務记在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在
# Real Translation: 确保亲自填写注册表格。
# BLEU Score:  0
# --------------------------------------------------------------------------------
# 152
# Input: better be the head of a cat than the tail of a lion .
# Predicted Translation: 對不起貓是貓比貓的鿄������������������������������
# Real Translation: 寧為貓頭不為獅尾。
# BLEU Score:  1.2183324802375697e-231
# --------------------------------------------------------------------------------
# 153
# Input: could you lend me your bicycle for a couple of days ?
# Predicted Translation: 你能把把你的腳踏車給我給我給我給我的借腳踏車借腳踏車借腳踏車借腳踏車借腳踏車借腳踏車借腳踏車借腳踏車借腳踏車借腳踏車借腳踏車借腳踏車借腳踏車借腳踏車借腳踏車借
# Real Translation: 你能把你的自行车借我两天吗？
# BLEU Score:  1.2730047079770533e-78
# --------------------------------------------------------------------------------
# 154
# Input: did you know that some foxes lived on this mountain ?
# Predicted Translation: 你告这个山是山有山，不是麼？
# Real Translation: 你知道有些狐狸住在這座山上嗎?
# BLEU Score:  1.1640469867513693e-231
# --------------------------------------------------------------------------------
# 155
# Input: do you know which deity this temple is dedicated to ?
# Predicted Translation: 这这这�这这这这这这这这这这这这这这这这这这这这这这这这这这这这这这这这这这这
# Real Translation: 您知道这座庙宇供奉的是哪个神吗？
# BLEU Score:  7.337741777064293e-232
# --------------------------------------------------------------------------------
# 156
# Input: don t translate english into japanese word for word .
# Predicted Translation: 不要地假往日語。
# Real Translation: 不要逐字逐句的把英文翻譯成日文。
# BLEU Score:  7.107197028258987e-232
# --------------------------------------------------------------------------------
# 157
# Input: everybody except tom knew he didn t need to do that .
# Predicted Translation: 除了每个人都都都都都都都都都都都都都都都都都都都都都都都都都都都都都都都都都都都都都都都
# Real Translation: 除了汤姆以外任何人都知道他没必要这么做。
# BLEU Score:  9.893133360884868e-232
# --------------------------------------------------------------------------------
# 158
# Input: flies and mosquitoes interfered with his meditation .
# Predicted Translation: 一隻阘���，他的生。
# Real Translation: 蒼蠅和蚊子干擾了他的冥想。
# BLEU Score:  3.645525559050358e-155
# --------------------------------------------------------------------------------
# 159
# Input: fluency in english is a very marketable skill today .
# Predicted Translation: 現在性的性的工利。
# Real Translation: 流利的英語在今天是一種十分搶手的技能。
# BLEU Score:  7.63718022611286e-232
# --------------------------------------------------------------------------------
# 160
# Input: foreign investors withdrew their money from america .
# Predicted Translation: 油中從大油錢。
# Real Translation: 外国投资者从美国收回他们的钱。
# BLEU Score:  7.060301868108111e-232
# --------------------------------------------------------------------------------
# 161
# Input: he called in to say he could not attend the meeting .
# Predicted Translation: 他必須在在在在會議。
# Real Translation: 他打電話來說他不會參加會議了。
# BLEU Score:  4.154122940232254e-155
# --------------------------------------------------------------------------------
# 162
# Input: he did not answer the phone , so i sent him an email .
# Predicted Translation: 他沒有他沒有他沒有他的電話。
# Real Translation: 他没有接电话，所以我给他发了封邮件。
# BLEU Score:  1.2395288183339461e-231
# --------------------------------------------------------------------------------
# 163
# Input: he has a wife and two young children to provide for .
# Predicted Translation: 他拥有個个女兒。
# Real Translation: 他有一个妻子和两个孩子要养活。
# BLEU Score:  8.324264127738903e-232
# --------------------------------------------------------------------------------
# 164
# Input: he is not the man that he was when i first knew him .
# Predicted Translation: 这不是我的男人的那个的那个的那个的那个的那个的那个的那个的那个的那个的那个的那个的那个的那个的那个的那个的那个的那个的那个的那个的那个的那个的那个的那个的那个的那个的那个的那个的那个的那个的那个的那个的那个的那个的那个的那个的那个的那个
# Real Translation: 他已经不是我最初见他那时的那个人了。
# BLEU Score:  9.071017449434147e-79
# --------------------------------------------------------------------------------
# 165
# Input: he left the house without so much as saying goodbye .
# Predicted Translation: 他根本就不再见。
# Real Translation: 他甚至没说再见就离开了家。
# BLEU Score:  8.451929273732148e-232
# --------------------------------------------------------------------------------
# 166
# Input: he must have said so without giving it much thought .
# Predicted Translation: 他用沒在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在
# Real Translation: 他一定没有多考虑就说了。
# BLEU Score:  7.244248269687037e-232
# --------------------------------------------------------------------------------
# 167
# Input: he never gave up hope that he would reach that goal .
# Predicted Translation: 他��������信������������������������������
# Real Translation: 他從沒放棄達成那個目標的希望。
# BLEU Score:  3.5384650434980955e-233
# --------------------------------------------------------------------------------
# 168
# Input: he pinched and scraped for many years to save money .
# Predicted Translation: 他努力着着着了三美元。
# Real Translation: 為了存錢他省吃儉用了許多年。
# BLEU Score:  7.942428204384923e-232
# --------------------------------------------------------------------------------
# 169
# Input: hey , i may have no money , but i still have my pride .
# Predicted Translation: 汤姆有，我有个錢。
# Real Translation: 嗨，我可能没钱，但我一直有我的骄傲。
# BLEU Score:  3.214641411992215e-155
# --------------------------------------------------------------------------------
# 170
# Input: his brazen act of defiance almost cost him his life .
# Predicted Translation: 他的寑����的。
# Real Translation: 他怀疑的无耻行为差点要了他的命。
# BLEU Score:  2.289194826804755e-155
# --------------------------------------------------------------------------------
# 171
# Input: his observations are sharp , but he doesn t say much .
# Predicted Translation: 他的观观观的观，但我太太太太太太太太太太太太太太太太太太太太太太太太太太太太太太太太
# Real Translation: 他的觀察是敏銳的，但他沒有說太多。
# BLEU Score:  5.253441210115029e-155
# --------------------------------------------------------------------------------
# 172
# Input: his son s criminal activities caused him great pain .
# Predicted Translation: 他的姧������������������������������������
# Real Translation: 他儿子的犯罪行为给他带来了很大的痛苦。
# BLEU Score:  1.2575191861870427e-232
# --------------------------------------------------------------------------------
# 173
# Input: how did tom talk mary into babysitting his children ?
# Predicted Translation: 这山������������������������������������
# Real Translation: 汤姆是怎么说服玛丽照顾他的小孩的呢？
# BLEU Score:  0
# --------------------------------------------------------------------------------
# 174
# Input: how long did you think the picnic was going to last ?
# Predicted Translation: “為為為野餐怎么能多久多久多久多久多久多久？
# Real Translation: 你認為野餐要多長時間？
# BLEU Score:  5.3448396730677054e-155
# --------------------------------------------------------------------------------
# 175
# Input: i can t concentrate on my work because of the noise .
# Predicted Translation: 我站，沒有在噪音。
# Real Translation: 由于噪音，我无法集中精力工作了。
# BLEU Score:  1.1931009847695213e-231
# --------------------------------------------------------------------------------
# 176
# Input: i can t take the place of her as an english teacher .
# Predicted Translation: 我們不能做她和她老師了。
# Real Translation: 我无法取代她做英语老师。
# BLEU Score:  1.384292958842266e-231
# --------------------------------------------------------------------------------
# 177
# Input: i plan to spend the new year s holiday in australia .
# Predicted Translation: 在月月們在日�在捶�。
# Real Translation: 我打算在澳大利亚过新年。
# BLEU Score:  1.0832677820940877e-231
# --------------------------------------------------------------------------------
# 178
# Input: i studied in the morning during the summer vacation .
# Predicted Translation: 他在夏天，夏天的时候用履������������睡覺。
# Real Translation: 我在暑假里早晨学习。
# BLEU Score:  1.1640469867513693e-231
# --------------------------------------------------------------------------------
# 179
# Input: i suspect that they water down the beer in that pub .
# Predicted Translation: 在裡在海的啤酒的啤酒都楡。
# Real Translation: 我怀疑那家酒馆的啤酒兑水了。
# BLEU Score:  6.061838450024688e-155
# --------------------------------------------------------------------------------
# 180
# Input: i think the time is right to introduce this product .
# Predicted Translation: 我在这个这个西�機。
# Real Translation: 我覺得現在是發表這個產品的好時機。
# BLEU Score:  3.532591656055112e-232
# --------------------------------------------------------------------------------
# 181
# Input: i think we should be able to go wherever we want to .
# Predicted Translation: 我觉得你们们们们該哪里。
# Real Translation: 我認為我們應該能去我們想去的地方。
# BLEU Score:  6.3597993332323924e-232
# --------------------------------------------------------------------------------
# 182
# Input: i think you should do that before you go home today .
# Predicted Translation: 我觉得你之前这回家。
# Real Translation: 我認為你該在今天回家前做。
# ...
# Real Translation: 他毫不犹豫地把自己的车卖了。
# BLEU Score:  8.412065649527267e-232
# --------------------------------------------------------------------------------
# 440
# Input: you continue making the same mistakes time after time .
# Predicted Translation: 你頭在过过在过过过过过过过过过过过过过过过过过过过过过过过过过过过过过过过过过过
# Real Translation: 你每次都继续犯同样的错误。
# BLEU Score:  7.244248269687037e-232
# --------------------------------------------------------------------------------
# 441
# Input: you look pale . you had better lie down in bed at once .
# Predicted Translation: 你看起来很们们地地地地地地地地地地地地地地地地地地地地地地地地地地地地地地地地地地地地地
# Real Translation: 你看上去很苍白。你最好立刻去床上躺会儿。
# BLEU Score:  8.460552185460498e-232
# --------------------------------------------------------------------------------
# 442
# Input: you need to attach your photo to the application form .
# Predicted Translation: 你有在�在�在在�在�在�在�庆在�在�在�在�在�在�在�在�在�在
# Real Translation: 你必须把你的照片贴在申请书上。
# BLEU Score:  1.0244914152188952e-231
# --------------------------------------------------------------------------------
# 443
# Input: you should ve done it earlier . it can t be helped now .
# Predicted Translation: 你们现在可以可以可以可以可以可以可以可以可以可以可以可以可以可以可以可以可以可以可以可以可以可以可以可以可以可以可以可以可以可以可以可以可以可以可以可以可以可以
# Real Translation: 你本应该早点做的。现在已经没有任何办法了。
# BLEU Score:  7.244248269687037e-232
# --------------------------------------------------------------------------------
# 444
# Input: you re the one who suggested that we do that together .
# Predicted Translation: 这一起去這屃我什么手，人去你看起来你看起来你看起来你看起来你看起来你看起来你看起来你看起来你看起来你看起来你看起来你看起来你看起来你看起来你看起来你看起来你看起来你看起来你看起来你看起来你看起来你看起来你看起来你看起来你看起来你看起来你看起来你看起来我什么湯姆說他
# Real Translation: 你是那個建議我們一起做那件事的人。
# BLEU Score:  8.127238000397563e-232
# --------------------------------------------------------------------------------
# 445
# Input: he d like to have a coffee after work . i would too .
# Predicted Translation: 他在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在
# Real Translation: "他想在下班後喝杯咖啡。" "我也想。"
# BLEU Score:  8.614911585158347e-232
# --------------------------------------------------------------------------------
# 446
# Input: how did you get my phone number ? tom gave it to me .
# Predicted Translation: 你怎么你怎么怎么號碼。”。”
# Real Translation: “你怎么知道我的电话号码的？” “汤姆告诉我的。”
# BLEU Score:  3.957979241501469e-155
# --------------------------------------------------------------------------------
# 447
# Input: according to tv news , there was a plane crash in india .
# Predicted Translation: 一一一一一一一一一一一一一一一一一一一一一一一一一一一一一一一一一一一一一一一一
# Real Translation: 根据电视新闻，一架飞机在印度坠毁了。
# BLEU Score:  8.510469113101058e-232
# --------------------------------------------------------------------------------
# 448
# Input: according to the weather forecast , it ll snow tomorrow .
# Predicted Translation: 在预的预喖���������聲的。
# Real Translation: 天气预报说明天会下雪。
# BLEU Score:  1.0832677820940877e-231
# --------------------------------------------------------------------------------
# 449
# Input: after i talked with my teacher , i decided to work hard .
# Predicted Translation: 我遇和的老師，我在用他的寯�����������������������������
# Real Translation: 跟我的老師談過後，我決定認真努力。
# BLEU Score:  3.1900611403603355e-78
# --------------------------------------------------------------------------------
# 450
# Input: after reading his books i feel i can construct a house .
# Predicted Translation: 我在看看書學習。
# Real Translation: 讀完他的書後，我覺得我可以構建一棟房子。
# BLEU Score:  3.0623256354760702e-232
# --------------------------------------------------------------------------------
# 451
# Input: all horses are animals , but not all animals are horses .
# Predicted Translation: “馬都，都有馬有馬有馬有馬有馬，都有馬，都有馬，都有馬，都有馬是馬是馬，都有馬，
# Real Translation: 所有的马都是动物，但并非所有的动物都是马。
# BLEU Score:  1.0832677820940877e-231
# --------------------------------------------------------------------------------
# 452
# Input: are there any direct flights between boston and sydney ?
# Predicted Translation: 在波士顿和班的班的班的飛機飛機飛機飛機的班班班班班班班班班班班飛機的班班班班班的班班班班班班班
# Real Translation: 请问波士顿和悉尼之间有直飞航班吗？
# BLEU Score:  3.0202505652128895e-155
# --------------------------------------------------------------------------------
# 453
# Input: as far as i know , there is nothing wrong with his plan .
# Predicted Translation: 据我所知如何有問題。
# Real Translation: 據我所知，他的計畫沒有出差錯。
# BLEU Score:  2.629987967659101e-78
# --------------------------------------------------------------------------------
# 454
# Input: be sure to drop us a line as soon as you get to london .
# Predicted Translation: 别忘了们們們們們們們們們們們們們們們們們們們們們們們們們們們們們們們們們們們們們們們
# Real Translation: 别忘了一到伦敦就给我们留言啊。
# BLEU Score:  1.1799147652163341e-78
# --------------------------------------------------------------------------------
# 455
# Input: being late is always better than not showing up at all .
# Predicted Translation: 一个在人总在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在
# Real Translation: 迟到总比不到好。
# BLEU Score:  7.244248269687037e-232
# --------------------------------------------------------------------------------
# 456
# Input: blenders are nice for people who really like smoothies .
# Predicted Translation: 往的外外外外外外外外外外外外外外外外外外外外外外外外外外外外外外外外外外外外外外
# Real Translation: 攪拌機對真的喜歡冰沙的人來說很不錯。
# BLEU Score:  7.244248269687037e-232
# --------------------------------------------------------------------------------
# 457
# Input: books are for people who wish they were somewhere else .
# Predicted Translation: 書是另一个的。
# Real Translation: 書是為了那些希望自己在另一個地方的人。
# BLEU Score:  2.1266336439355304e-155
# --------------------------------------------------------------------------------
# 458
# Input: did you remember that you were supposed to buy candles ?
# Predicted Translation: “你都不買家，您要您要有很多火家火家火家火嗎�火。
# Real Translation: 你记得自己该买蜡烛吗？
# BLEU Score:  8.319100378795605e-232
# --------------------------------------------------------------------------------
# 459
# Input: do you want to get married first or have a child first ?
# Predicted Translation: “一个先先做的結婚
# Real Translation: 你想我们先结婚还是先生孩子？
# BLEU Score:  1.0032743411283238e-231
# --------------------------------------------------------------------------------
# 460
# Input: don t be afraid to make mistakes when speaking english .
# Predicted Translation: 别们守外外外外外外外外外外外外外外外外外外外外外外外外外外外外外外外外外外外外外
# Real Translation: 說英語的時候不要怕犯錯。
# BLEU Score:  0
# --------------------------------------------------------------------------------
# 461
# Input: don t be afraid to make mistakes when speaking english .
# Predicted Translation: 别们守外外外外外外外外外外外外外外外外外外外外外外外外外外外外外外外外外外外外外
# Real Translation: 當你說英語的時候不要怕犯錯。
# BLEU Score:  0
# --------------------------------------------------------------------------------
# 462
# Input: ebola is one of the most virulent viruses known to man .
# Predicted Translation: 祌�������������������������������������
# Real Translation: 埃博拉是人类已知的最致命的病毒之一。
# BLEU Score:  0
# --------------------------------------------------------------------------------
# 463
# Input: finishing the report by tomorrow is next to impossible .
# Predicted Translation: 明天明天在明天是明天是不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不
# Real Translation: 在明天前完成报告几乎是不可能的。
# BLEU Score:  3.991752103918031e-155
# --------------------------------------------------------------------------------
# 464
# Input: from the look of the sky , it may rain in the afternoon .
# Predicted Translation: 在的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的
# Real Translation: 從天色看起來，下午可能會下雨。
# BLEU Score:  0
# --------------------------------------------------------------------------------
# 465
# Input: germany adopted a social security system in the s .
# Predicted Translation: 我接受的帤�都有身。
# Real Translation: 德国在1880年代采取了一种社会保障制度。
# BLEU Score:  6.570351225189682e-232
# --------------------------------------------------------------------------------
# 466
# Input: he doesn t have any knowledge about american democracy .
# Predicted Translation: 他不是多有關的金的知。
# Real Translation: 他一点都不知道美国的民主。
# BLEU Score:  1.4147351699132998e-231
# --------------------------------------------------------------------------------
# 467
# Input: he doesn t know the difference between right and wrong .
# Predicted Translation: 他不知道的外下不動。
# Real Translation: 他好坏不分。
# BLEU Score:  1.384292958842266e-231
# --------------------------------------------------------------------------------
# 468
# Input: he went on reading the book as if nothing had happened .
# Predicted Translation: 他正在書地在一覺得。
# Real Translation: 他繼續讀書，好像什麼事也沒有發生。
# BLEU Score:  6.3597993332323924e-232
# --------------------------------------------------------------------------------
# 469
# Input: his record is a new world record in the meter dash .
# Predicted Translation: 他的动的常����������������������������������
# Real Translation: 他刷新了百米短跑的世界紀錄。
# BLEU Score:  6.016112399618114e-232
# --------------------------------------------------------------------------------
# 470
# Input: i can t believe tom was able to do this all by himself .
# Predicted Translation: 這個信里有自己做。
# Real Translation: 没法相信，汤姆没人帮助自己一个人就做到了这些。
# BLEU Score:  4.739132419722992e-232
# --------------------------------------------------------------------------------
# 471
# Input: i can t survive without air conditioning in the summer .
# Predicted Translation: 炎夏天，夏天在平在平存在。
# Real Translation: 我夏天没有空调会死。
# BLEU Score:  1.2183324802375697e-231
# --------------------------------------------------------------------------------
# 472
# Input: i don t know where my crutches are . have you seen them ?
# Predicted Translation: “你的腳都腳都腳都腳都腳都腳都腳都腳都腳都腳都腳都腳都腳都腳都腳都腳都腳在哪裡。
# Real Translation: 我不知道把拐杖放哪去了，你有看到嗎？
# BLEU Score:  8.614911585158347e-232
# --------------------------------------------------------------------------------
# 473
# Input: i don t want to go there . he doesn t want to go either .
# Predicted Translation: 不知道他想去那裡。
# Real Translation: 我不想去那儿，他也不想。
# BLEU Score:  5.60411810495621e-155
# --------------------------------------------------------------------------------
# 474
# Input: i felt so sleepy that i could hardly keep my eyes open .
# Predicted Translation: 我悎��，我，我还��著我还著。
# Real Translation: 我感觉困得几乎不能睁开我的眼睛了。
# BLEU Score:  1.090462944153118e-231
# --------------------------------------------------------------------------------
# 475
# Input: i found a good place to buy fruit a couple of days ago .
# Predicted Translation: 我在给一條買了一條商店。
# Real Translation: 前几天我发现了一个买水果的好地方。
# BLEU Score:  8.875814970513353e-232
# --------------------------------------------------------------------------------
# 476
# Input: i know that it is highly unlikely that anyone knows me .
# Predicted Translation: 我知道个人都知道我的知道我的知道我的知道我的知道我的知道我的知道我的知道我的知道我的知道我的知道我的知道我的知道我的知道我的知道我的知道我的知道我的知道我的
# Real Translation: 我知道有人认识我的可能性微乎其微。
# BLEU Score:  3.3084075264006686e-155
# --------------------------------------------------------------------------------
# 477
# Input: i look forward to hearing your thoughts on this matter .
# Predicted Translation: 我想你的感受上上上上上上上上上上上上上上上上上上上上上上上上上上上上上上上上上上上上
# Real Translation: 我期待听到你在这件事上的想法 。
# BLEU Score:  1.0181865532756278e-231
# --------------------------------------------------------------------------------
# 478
# Input: i lost my job and i have no money . i m at my wit s end .
# Predicted Translation: 我辞轤，我的錢。
# Real Translation: 我失業又沒錢。真不知該何去何從。
# BLEU Score:  2.9915609182707424e-155
# --------------------------------------------------------------------------------
# 479
# Input: i never answer email messages from people i don t know .
# Predicted Translation: 我還沒有不写人邮的邮的邮的邮的邮的邮的邮的邮的邮的邮的邮的邮的邮的邮的邮的邮的邮的邮的
# Real Translation: 我从不回复陌生人发来的电子邮件。
# BLEU Score:  9.363140134330432e-232
# --------------------------------------------------------------------------------
# 480
# Input: i really look forward to your visit in the near future .
# Predicted Translation: 我真的很想您的光光光光光光光光光光光光光光光光光光光光光光光光光光光光光光光光光光光光光
# Real Translation: 我很期待在不久的將來您的光臨。
# BLEU Score:  2.0339968208213956e-78
# --------------------------------------------------------------------------------
# 481
# Input: i studied english for four years with a native speaker .
# Predicted Translation: 我在一年�。
# Real Translation: 我跟英语母语者学了四年英语。
# BLEU Score:  4.3638512969692e-232
# --------------------------------------------------------------------------------
# 482
# Input: i was quite thirsty and wanted to drink something cool .
# Predicted Translation: 我覺得一點喝点酷。
# Real Translation: 我很渴，想喝点冷饮。
# BLEU Score:  7.241926111174567e-155
# --------------------------------------------------------------------------------
# 483
# Input: i m afraid i can t help you . you must ask someone else .
# Predicted Translation: 我現在，我無法讓你。
# Real Translation: 我担心可能帮不了你，你需要找其他人帮忙。
# BLEU Score:  8.78771736427028e-232
# --------------------------------------------------------------------------------
# 484
# Input: i m surprised that you don t know about their marriage .
# Predicted Translation: 我聽說了他们的婚感到知道你。
# Real Translation: 我很惊讶，你竟然不知道他们结婚。
# BLEU Score:  1.4959003140449574e-231
# --------------------------------------------------------------------------------
# 485
# Input: if you are not going to the concert , then neither am i .
# Predicted Translation: “你去来不去，我没有你去�在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在
# Real Translation: 如果你不去音樂會, 我也不去。
# BLEU Score:  3.421647610625111e-155
# --------------------------------------------------------------------------------
# 486
# Input: instead of going to europe , i decided to go to america .
# Predicted Translation: 没有住在不去，我还遊。
# Real Translation: 我决定去美国，而不是欧洲。
# BLEU Score:  1.5319719891192393e-231
# --------------------------------------------------------------------------------
# 487
# Input: iron the inside of collars first , and then the outside .
# Predicted Translation: 用在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在在
# Real Translation: 先熨烫领子的里面，然后是外面。
# BLEU Score:  0
# --------------------------------------------------------------------------------
# 488
# Input: it takes years for neptune to orbit around the sun .
# Predicted Translation: 一个著著著著著著著著著著著著著著著著著著著著著著著著著著著著著著著著著著著著著著著
# Real Translation: 海王星繞行太陽一周要花一百六十五年。
# BLEU Score:  0
# --------------------------------------------------------------------------------
# 489
# Input: it was not until i reached home that i missed my purse .
# Predicted Translation: 那么的，我之前家的时候丢了家家家家家家家家家家家家家家家家家家家家家家家家家家家家家家家家
# Real Translation: 那是在我到家以后，我才不见了我的钱包。
# BLEU Score:  4.417599881331674e-155
# --------------------------------------------------------------------------------
# 490
# Input: it would be wonderful if you could sing at our wedding .
# Predicted Translation: 在們在們在們唱歌。
# Real Translation: 你能在我们的婚礼上唱歌就太好了。
# BLEU Score:  7.631011170724675e-232
# --------------------------------------------------------------------------------
# 491
# Input: it s easy to make friends , but hard to get rid of them .
# Predicted Translation: 這是人做的时候的时候的时候的时候的时候的时候的时候的时候的时候的时候的时候的时候的时候的时候的时候的时候的时候的时候的时候的时候的时候的时候的时候的时候的时候的时候的时候的时候的时候的时候的时候的时候的时候的时候的时候的时候的时候
# Real Translation: 交朋友很容易, 但擺脫他們很難。
# BLEU Score:  0
# --------------------------------------------------------------------------------
# 492
# Input: it s not that easy to learn a new language after fifty .
# Predicted Translation: 後在那裡是不请��的。
# Real Translation: 五十岁以后学一门新的语言不是那么容易。
# BLEU Score:  7.942428204384923e-232
# --------------------------------------------------------------------------------
# 493
# Input: it s up to you to decide whether we ll go there or not .
# Predicted Translation: 这现在怎么該去哪裡。
# Real Translation: 该由你来决定我们去不去那儿。
# BLEU Score:  8.853864984883467e-232
# --------------------------------------------------------------------------------
# 494
# Input: judging from the look of the sky , it is likely to rain .
# Predicted Translation: 墢�������������������������������������
# Real Translation: 看看天的样子，要下雨了。
# BLEU Score:  0
# --------------------------------------------------------------------------------
# 495
# Input: kissing a person who smokes is like licking an ashtray .
# Predicted Translation: 有人有人有人在有人抽個吸煙很加加加加加加加加加加加加加加加加加加加加加加加加加加加加加加加
# Real Translation: 亲吻一个抽烟的人就像在舔烟灰缸。
# BLEU Score:  1.1008876702055895e-231
# --------------------------------------------------------------------------------
# 496
# Input: lake baikal in russia is the deepest lake in the world .
# Predicted Translation: 在湖是的水最深的的嵖最湖最�水的。
# Real Translation: 在俄羅斯的貝加爾湖是世界上最深的湖泊。
# BLEU Score:  3.335498070913389e-78
# --------------------------------------------------------------------------------
# 497
# Input: lake baikal in russia is the deepest lake in the world .
# Predicted Translation: 在湖是的水最深的的嵖最湖最�水的。
# Real Translation: 俄羅斯的貝加爾湖是世界上最深的湖泊。
# BLEU Score:  3.434046030282548e-78
# --------------------------------------------------------------------------------

# %%
bleuplus/498
# Out:
# 0.002440708527898148

# %%
# !pip install pynlpir
# Out:
# Collecting pynlpir
#   Downloading PyNLPIR-0.6.0-py2.py3-none-any.whl (13.1 MB)
# Requirement already satisfied: click in c:\users\user\anaconda3\envs\tf-gpu-env\lib\site-packages (from pynlpir) (7.1.2)
# Installing collected packages: pynlpir
# Successfully installed pynlpir-0.6.0

# %%
# pynlpir.open()
# mystring = "你汉语说的很好！"
# tokenized_string = pynlpir.segment(mystring, pos_tagging=False)

# %%
# tokenized_string
# Out:
# ['你', '汉语', '说', '的', '很', '好', '！']

# %%
# predicted = translate(new_transformer, en_val[0])
# Out:
# Input: what would you do if you had ten thousand dollars ?
# Predicted Translation: 如果我个二里做什麼的?

# %%
# two_ = pynlpir.segment(predicted, pos_tagging=False)

# %%
# one_ = pynlpir.segment(chi_val[0], pos_tagging=False)

# %%
# bleu.sentence_bleu([one_], two_)
# Out:
# 9.97486269044271e-232

# %%
# pynlpir.segment("他不法來我裡關�利。", pos_tagging=False)
# Out:
# ['他', '不法', '來', '我', '裡', '關', '�利', '。']

# %%
# s = SnowNLP(他頭地尕����������������������������������)
# s.words
# Out:
#   File "<ipython-input-81-9e7aba872beb>", line 1
#     s = SnowNLP(他頭地尕����������������������������������)
#                                                      ^
# SyntaxError: invalid character in identifier
